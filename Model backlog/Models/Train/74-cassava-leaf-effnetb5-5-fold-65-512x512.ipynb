# %% [markdown]
# ## Dependencies

# %%
# !pip install --quiet efficientnet
# Out:
# WARNING: You are using pip version 20.1.1; however, version 21.0 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
import warnings, time
from kaggle_datasets import KaggleDatasets
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras import optimizers, Sequential, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping
import efficientnet.tfkeras as efn
from cassava_scripts import *
from scripts_step_lr_schedulers import *


seed = 0
seed_everything(seed)
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Hardware configuration

# %%
# TPU or GPU detection
# Detect hardware, return appropriate distribution strategy
strategy, tpu = set_up_strategy()

AUTO = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Model parameters

# %%
BATCH_SIZE = 8 * REPLICAS
LEARNING_RATE = 1e-5 * REPLICAS
EPOCHS = 33
HEIGHT = 512
WIDTH = 512
HEIGHT_DT = 512
WIDTH_DT = 512
CHANNELS = 3
N_CLASSES = 5
N_FOLDS = 5
FOLDS_USED = 5
ES_PATIENCE = 10

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/cassava-leaf-disease-classification/'
train = pd.read_csv(f'{database_base_path}train.csv')
print(f'Train samples: {len(train)}')

GCS_PATH = KaggleDatasets().get_gcs_path(f'cassava-leaf-disease-tfrecords-center-{HEIGHT_DT}x{WIDTH_DT}') # Center croped and resized (50 TFRecord)
GCS_PATH_EXT = KaggleDatasets().get_gcs_path(f'cassava-leaf-disease-tfrecords-external-{HEIGHT_DT}x{WIDTH_DT}') # Center croped and resized (50 TFRecord) (External)
GCS_PATH_CLASSES = KaggleDatasets().get_gcs_path(f'cassava-leaf-disease-tfrecords-classes-{HEIGHT_DT}x{WIDTH_DT}') # Center croped and resized (50 TFRecord) by classes
GCS_PATH_EXT_CLASSES = KaggleDatasets().get_gcs_path(f'cassava-leaf-disease-tfrecords-classes-ext-{HEIGHT_DT}x{WIDTH_DT}') # Center croped and resized (50 TFRecord) (External) by classes


FILENAMES_COMP = tf.io.gfile.glob(GCS_PATH + '/*.tfrec')
FILENAMES_2019 = tf.io.gfile.glob(GCS_PATH_EXT + '/*.tfrec')

# FILENAMES_COMP_CBB = tf.io.gfile.glob(GCS_PATH_CLASSES + '/CBB*.tfrec')
# FILENAMES_COMP_CBSD = tf.io.gfile.glob(GCS_PATH_CLASSES + '/CBSD*.tfrec')
# FILENAMES_COMP_CGM = tf.io.gfile.glob(GCS_PATH_CLASSES + '/CGM*.tfrec')
# FILENAMES_COMP_CMD = tf.io.gfile.glob(GCS_PATH_CLASSES + '/CMD*.tfrec')
# FILENAMES_COMP_Healthy = tf.io.gfile.glob(GCS_PATH_CLASSES + '/Healthy*.tfrec')

# FILENAMES_2019_CBB = tf.io.gfile.glob(GCS_PATH_EXT_CLASSES + '/CBB*.tfrec')
# FILENAMES_2019_CBSD = tf.io.gfile.glob(GCS_PATH_EXT_CLASSES + '/CBSD*.tfrec')
# FILENAMES_2019_CGM = tf.io.gfile.glob(GCS_PATH_EXT_CLASSES + '/CGM*.tfrec')
# FILENAMES_2019_CMD = tf.io.gfile.glob(GCS_PATH_EXT_CLASSES + '/CMD*.tfrec')
# FILENAMES_2019_Healthy = tf.io.gfile.glob(GCS_PATH_EXT_CLASSES + '/Healthy*.tfrec')


TRAINING_FILENAMES = (FILENAMES_COMP + FILENAMES_2019)

NUM_TRAINING_IMAGES = count_data_items(TRAINING_FILENAMES)

print(f'GCS: train images: {NUM_TRAINING_IMAGES}')
display(train.head())
# Out:
# Train samples: 21397
# GCS: train images: 26335
#          image_id  label
# 0  1000015157.jpg      0
# 1  1000201771.jpg      3
# 2   100042118.jpg      1
# 3  1000723321.jpg      1
# 4  1000812911.jpg      3

# %% [markdown]
# # Augmentation

# %%
def data_augment(image, label):
#     p_rotation = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_spatial = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_rotate = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_pixel_1 = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_pixel_2 = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_pixel_3 = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
#     p_shear = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_crop = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_cutout = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    
#     # Shear
#     if p_shear > .2:
#         if p_shear > .6:
#             image = transform_shear(image, HEIGHT, shear=20.)
#         else:
#             image = transform_shear(image, HEIGHT, shear=-20.)
            
#     # Rotation
#     if p_rotation > .2:
#         if p_rotation > .6:
#             image = transform_rotation(image, HEIGHT, rotation=45.)
#         else:
#             image = transform_rotation(image, HEIGHT, rotation=-45.)
            
    # Flips
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    if p_spatial > .75:
        image = tf.image.transpose(image)
        
    # Rotates
    if p_rotate > .75:
        image = tf.image.rot90(image, k=3) # rotate 270º
    elif p_rotate > .5:
        image = tf.image.rot90(image, k=2) # rotate 180º
    elif p_rotate > .25:
        image = tf.image.rot90(image, k=1) # rotate 90º
        
    # Pixel-level transforms
    if p_pixel_1 >= .4:
        image = tf.image.random_saturation(image, lower=.7, upper=1.3)
    if p_pixel_2 >= .4:
        image = tf.image.random_contrast(image, lower=.8, upper=1.2)
    if p_pixel_3 >= .4:
        image = tf.image.random_brightness(image, max_delta=.1)
        
    # Crops
    if p_crop > .6:
        if p_crop > .9:
            image = tf.image.central_crop(image, central_fraction=.5)
        elif p_crop > .8:
            image = tf.image.central_crop(image, central_fraction=.6)
        elif p_crop > .7:
            image = tf.image.central_crop(image, central_fraction=.7)
        else:
            image = tf.image.central_crop(image, central_fraction=.8)
    elif p_crop > .3:
        crop_size = tf.random.uniform([], int(HEIGHT*.6), HEIGHT, dtype=tf.int32)
        image = tf.image.random_crop(image, size=[crop_size, crop_size, CHANNELS])
            
    image = tf.image.resize(image, size=[HEIGHT, WIDTH])

    if p_cutout > .5:
        image = data_augment_cutout(image)
        
    return image, label

# %% [markdown]
# ## Auxiliary functions

# %%
# CutOut
def data_augment_cutout(image, min_mask_size=(int(HEIGHT * .1), int(HEIGHT * .1)), 
                        max_mask_size=(int(HEIGHT * .125), int(HEIGHT * .125))):
    p_cutout = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    
    if p_cutout > .85: # 10~15 cut outs
        n_cutout = tf.random.uniform([], 10, 15, dtype=tf.int32)
        image = random_cutout(image, HEIGHT, WIDTH, 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=n_cutout)
    elif p_cutout > .6: # 5~10 cut outs
        n_cutout = tf.random.uniform([], 5, 10, dtype=tf.int32)
        image = random_cutout(image, HEIGHT, WIDTH, 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=n_cutout)
    elif p_cutout > .25: # 2~5 cut outs
        n_cutout = tf.random.uniform([], 2, 5, dtype=tf.int32)
        image = random_cutout(image, HEIGHT, WIDTH, 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=n_cutout)
    else: # 1 cut out
        image = random_cutout(image, HEIGHT, WIDTH, 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=1)

    return image

# %%
# Datasets utility functions
def random_crop(image, label):
    """
        Resize and reshape images to the expected size.
    """
    image = tf.image.random_crop(image, size=[HEIGHT, WIDTH, CHANNELS])
    return image, label

def prepare_image(image, label):
    """
        Resize and reshape images to the expected size.
    """
    image = tf.image.resize(image, [HEIGHT, WIDTH])
    image = tf.reshape(image, [HEIGHT, WIDTH, CHANNELS])
    return image, label

def center_crop_(image, label, height_rs, width_rs, height=HEIGHT_DT, width=WIDTH_DT, channels=3):
    image = tf.reshape(image, [height, width, channels]) # Original shape
    
    h, w = image.shape[0], image.shape[1]
    if h > w:
        image = tf.image.crop_to_bounding_box(image, (h - w) // 2, 0, w, w)
    else:
        image = tf.image.crop_to_bounding_box(image, 0, (w - h) // 2, h, h)
        
    image = tf.image.resize(image, [height_rs, width_rs]) # Expected shape
    return image, label

def get_dataset(filenames, labeled=True, ordered=False, repeated=False, 
                cached=False, augment=False):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    
    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False
        dataset = tf.data.Dataset.list_files(filenames)
        dataset = dataset.interleave(tf.data.TFRecordDataset, num_parallel_calls=AUTO)
    else:
        dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTO)
        
    dataset = dataset.with_options(ignore_order)
    
    dataset = dataset.map(lambda x: read_tfrecord(x, labeled=labeled), num_parallel_calls=AUTO)
    
    if augment:
        dataset = dataset.map(data_augment, num_parallel_calls=AUTO)
        
    dataset = dataset.map(scale_image, num_parallel_calls=AUTO)
    dataset = dataset.map(prepare_image, num_parallel_calls=AUTO)
    
    
    if labeled:
        dataset = dataset.map(conf_output, num_parallel_calls=AUTO)
    
    
    if not ordered:
        dataset = dataset.shuffle(2048)
    if repeated:
        dataset = dataset.repeat()
        
    dataset = dataset.batch(BATCH_SIZE)
    
    if cached:
        dataset = dataset.cache()
    dataset = dataset.prefetch(AUTO)
    return dataset

def conf_output(image, label):
    """
        Configure the output of the dataset.
    """
    aux_label = [0.]
    aux_2_label = [0.]
    if tf.math.argmax(label, axis=-1) == 4: # Healthy
        aux_label = [1.]
    if tf.math.argmax(label, axis=-1) == 3: # CMD
        aux_2_label = [1.]
    return (image, (label, aux_label, aux_2_label))

# %% [markdown]
# # Training data samples (with augmentation)

# %%
# train_dataset = get_dataset(FILENAMES_COMP, ordered=True, augment=True)
# train_iter = iter(train_dataset.unbatch().batch(20))

# display_batch_of_images(next(train_iter))
# display_batch_of_images(next(train_iter))

# %% [markdown]
# # Model

# %%
def model_fn(input_shape, N_CLASSES):
    inputs = L.Input(shape=input_shape, name='input_image')
    base_model = efn.EfficientNetB5(input_tensor=inputs, 
                                    include_top=False, 
                                    weights='noisy-student', 
                                    pooling='avg')

    base_model.trainable = False

    x = L.Dropout(.25)(base_model.output)
    output = L.Dense(N_CLASSES, activation='softmax', name='output')(x)
    output_healthy = L.Dense(1, activation='sigmoid', name='output_healthy')(x)
    output_cmd = L.Dense(1, activation='sigmoid', name='output_cmd')(x)
    
    model = Model(inputs=inputs, outputs=[output, output_healthy, output_cmd])

    return model

# %% [markdown]
# ### Learning rate schedule

# %%
lr_start = 1e-8
lr_min = 1e-6
lr_max = LEARNING_RATE
num_cycles = 3.
warmup_epochs = 3
hold_max_epochs = 0
total_epochs = EPOCHS
step_size = (NUM_TRAINING_IMAGES//BATCH_SIZE)
hold_max_steps = hold_max_epochs * step_size
total_steps = total_epochs * step_size
warmup_steps = warmup_epochs * step_size


def lrfn(total_steps, warmup_steps=0, lr_start=1e-4, lr_max=1e-3, lr_min=1e-4, num_cycles=1.):
    @tf.function
    def cosine_with_hard_restarts_schedule_with_warmup_(step):
        """ Create a schedule with a learning rate that decreases following the
        values of the cosine function with several hard restarts, after a warmup
        period during which it increases linearly between 0 and 1.
        """

        if step < warmup_steps:
            lr = (lr_max - lr_start) / warmup_steps * step + lr_start
        else:
            progress = (step - warmup_steps) / (total_steps - warmup_steps)
            lr = lr_max * (0.5 * (1.0 + tf.math.cos(np.pi * ((num_cycles * progress) % 1.0))))
            if lr_min is not None:
                lr = tf.math.maximum(lr_min, float(lr))
        return lr
    return cosine_with_hard_restarts_schedule_with_warmup_

lrfn_fn = lrfn(total_steps, warmup_steps, lr_start, lr_max, lr_min, num_cycles)
rng = [i for i in range(total_steps)]
y = [lrfn_fn(tf.cast(x, tf.float32)) for x in rng]

sns.set(style='whitegrid')
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)

print(f'{total_steps} total steps and {step_size} steps per epoch')
print(f'Learning rate schedule: {y[0]:.3g} to {max(y):.3g} to {y[-1]:.3g}')
# Out:
# 13563 total steps and 411 steps per epoch
# Learning rate schedule: 1e-08 to 8e-05 to 1e-06

# %% [markdown]
# # Training

# %%
skf = KFold(n_splits=N_FOLDS, shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; oof_names = []; oof_folds = []; history_list = []

for fold,(idxT, idxV) in enumerate(skf.split(np.arange(15))):
    if fold >= FOLDS_USED:
        break
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    K.clear_session()
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {idxT} VALID: {idxV}')

    # Create train and validation sets
    FILENAMES_COMP = tf.io.gfile.glob([GCS_PATH + '/Id_train%.2i*.tfrec' % x for x in idxT])
    FILENAMES_2019 = tf.io.gfile.glob([GCS_PATH_EXT + '/Id_train%.2i*.tfrec' % x for x in idxT])

#     FILENAMES_COMP_CBB = tf.io.gfile.glob([GCS_PATH_CLASSES + '/CBB%.2i*.tfrec' % x for x in idxT])
#     FILENAMES_COMP_CBSD = tf.io.gfile.glob([GCS_PATH_CLASSES + '/CBSD%.2i*.tfrec' % x for x in idxT])
#     FILENAMES_COMP_CGM = tf.io.gfile.glob([GCS_PATH_CLASSES + '/CGM%.2i*.tfrec' % x for x in idxT])
#     FILENAMES_COMP_Healthy = tf.io.gfile.glob([GCS_PATH_CLASSES + '/Healthy%.2i*.tfrec' % x for x in idxT])
    
#     FILENAMES_2019_CBB = tf.io.gfile.glob([GCS_PATH_EXT_CLASSES + '/CBB%.2i*.tfrec' % x for x in idxT])
#     FILENAMES_2019_CBSD = tf.io.gfile.glob([GCS_PATH_EXT_CLASSES + '/CBSD%.2i*.tfrec' % x for x in idxT])
#     FILENAMES_2019_CGM = tf.io.gfile.glob([GCS_PATH_EXT_CLASSES + '/CGM%.2i*.tfrec' % x for x in idxT])
#     FILENAMES_2019_Healthy = tf.io.gfile.glob([GCS_PATH_EXT_CLASSES + '/Healthy%.2i*.tfrec' % x for x in idxT])

    TRAIN_FILENAMES = (FILENAMES_COMP + FILENAMES_2019)
    
    VALID_FILENAMES = tf.io.gfile.glob([GCS_PATH + '/Id_train%.2i*.tfrec' % x for x in idxV])
    np.random.shuffle(TRAIN_FILENAMES)
    
    ct_train = count_data_items(TRAIN_FILENAMES)
    ct_valid = count_data_items(VALID_FILENAMES)
    
    step_size = (ct_train // BATCH_SIZE)
    valid_step_size = (ct_valid // BATCH_SIZE)
    total_steps = (total_epochs * step_size)
    warmup_steps = (warmup_epochs * step_size)
    
    
    # Build TF datasets
    train_ds = strategy.experimental_distribute_dataset(get_dataset(TRAIN_FILENAMES, repeated=True, augment=True))
    valid_ds = strategy.experimental_distribute_dataset(get_dataset(VALID_FILENAMES, ordered=True, repeated=True))
    train_data_iter = iter(train_ds)
    valid_data_iter = iter(valid_ds)
    
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss = loss_fn(y[0], probabilities[0], label_smoothing=.3)
                aux_loss = aux_loss_fn(y[1], probabilities[1], label_smoothing=.1) * 0.1 # loss weight
                aux_2_loss = aux_2_loss_fn(y[2], probabilities[2], label_smoothing=.1) * 0.1 # loss weight
                loss = loss + aux_loss + aux_2_loss
            gradients = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(gradients, model.trainable_variables))
            # update metrics
            train_accuracy.update_state(y[0], probabilities[0])
            train_aux_accuracy.update_state(y[1], probabilities[1])
            train_aux_2_accuracy.update_state(y[2], probabilities[2])
            train_loss.update_state(loss)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss = loss_fn(y[0], probabilities[0])
            aux_loss = aux_loss_fn(y[1], probabilities[1]) * 0.1 # loss weight
            aux_2_loss = aux_2_loss_fn(y[2], probabilities[2]) * 0.1 # loss weight
            loss = loss + aux_loss + aux_2_loss
            # update metrics
            valid_accuracy.update_state(y[0], probabilities[0])
            valid_aux_accuracy.update_state(y[1], probabilities[1])
            valid_aux_2_accuracy.update_state(y[2], probabilities[2])
            valid_loss.update_state(loss)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))
    
    
    # Model
    model_path = f'model_{fold}.h5'
    with strategy.scope():
        model = model_fn((None, None, CHANNELS), N_CLASSES)
        unfreeze_model(model) # unfreeze all layers except "batch normalization"
        
        lrfn_fn = lrfn(total_steps, warmup_steps, lr_start, lr_max, lr_min, num_cycles)
        optimizer = optimizers.SGD(learning_rate=lambda: lrfn_fn(tf.cast(optimizer.iterations, tf.float32)), 
                                   momentum=0.95, nesterov=True)
        loss_fn = losses.categorical_crossentropy
        aux_loss_fn = losses.binary_crossentropy
        aux_2_loss_fn = losses.binary_crossentropy

        train_accuracy = metrics.CategoricalAccuracy()
        valid_accuracy = metrics.CategoricalAccuracy()
        train_aux_accuracy = metrics.BinaryAccuracy()
        valid_aux_accuracy = metrics.BinaryAccuracy()
        train_aux_2_accuracy = metrics.BinaryAccuracy()
        valid_aux_2_accuracy = metrics.BinaryAccuracy()
        train_loss = metrics.Sum()
        valid_loss = metrics.Sum()
        
        metrics_list = [train_accuracy, 
                        valid_accuracy, 
                        train_aux_accuracy, 
                        valid_aux_accuracy, 
                        train_aux_2_accuracy, 
                        valid_aux_2_accuracy, 
                        train_loss, 
                        valid_loss]
    
    
    # Setup training loop
    step = 0
    epoch_steps = 0
    patience_cnt = 0
    best_val = 0
    history = {'loss': [], 'val_loss': [], 
               'accuracy': [], 'val_accuracy': [], 
               'accuracy_aux': [], 'val_accuracy_aux': [], 
               'accuracy_aux_2': [], 'val_accuracy_aux_2': []}

    ### Train model
    for epoch in range(EPOCHS):
        epoch_start_time = time.time()

        # Run training step
        train_step(train_data_iter)
        epoch_steps += step_size
        step += step_size
            

        # Validation run at the end of each epoch
        if (step // step_size) > epoch:
            # Validation run
            valid_epoch_steps = 0
            valid_step(valid_data_iter)
            valid_epoch_steps += valid_step_size

            # Compute metrics
            history['accuracy_aux_2'].append(train_aux_2_accuracy.result().numpy())
            history['accuracy_aux'].append(train_aux_accuracy.result().numpy())
            history['accuracy'].append(train_accuracy.result().numpy())
            history['loss'].append(train_loss.result().numpy() / (BATCH_SIZE * epoch_steps))
            history['val_accuracy_aux_2'].append(valid_aux_2_accuracy.result().numpy())
            history['val_accuracy_aux'].append(valid_aux_accuracy.result().numpy())
            history['val_accuracy'].append(valid_accuracy.result().numpy())
            history['val_loss'].append(valid_loss.result().numpy() / (BATCH_SIZE * valid_epoch_steps))

            # Report metrics
            epoch_time = time.time() - epoch_start_time
            print(f'\nEPOCH {epoch+1}/{EPOCHS}')
            print(f'time: {epoch_time:0.1f}s',
                  f"loss: {history['loss'][-1]:0.4f}",
                  f"accuracy_aux_2: {history['accuracy_aux_2'][-1]:0.4f}",
                  f"accuracy_aux: {history['accuracy_aux'][-1]:0.4f}",
                  f"accuracy: {history['accuracy'][-1]:0.4f}",
                  f"val_loss: {history['val_loss'][-1]:0.4f}",
                  f"val_accuracy_aux_2: {history['val_accuracy_aux_2'][-1]:0.4f}",
                  f"val_accuracy_aux: {history['val_accuracy_aux'][-1]:0.4f}",
                  f"val_accuracy: {history['val_accuracy'][-1]:0.4f}",
                  f'lr: {lrfn_fn(tf.cast(optimizer.iterations, tf.int32).numpy()):0.4g}')

            # Early stopping monitor
            if history['val_accuracy'][-1] >= best_val:
                best_val = history['val_accuracy'][-1]
                model.save_weights(model_path)
                print(f'Saved model weights at "{model_path}"')
                patience_cnt = 1
            else:
                patience_cnt += 1
            if patience_cnt > ES_PATIENCE:
                print(f'Epoch {epoch:05d}: early stopping')
                break

                
            # Set up next epoch
            epoch_steps = 0
            for metric in metrics_list:
                metric.reset_states()
    
    
    ### RESULTS
    print(f"#### FOLD {fold+1} OOF Accuracy = {np.max(history['val_accuracy']):.3f}")
    
    history_list.append(history)
    # Load best model weights
    model.load_weights(model_path)

    # OOF predictions
    ds_valid = get_dataset(VALID_FILENAMES, ordered=True)
    oof_folds.append(np.full((ct_valid), fold, dtype='int8'))
    oof_labels.append([target[0].numpy() for img, target in iter(ds_valid.unbatch())])
    x_oof = ds_valid.map(lambda image, target: image)
    oof_pred.append(np.argmax(model.predict(x_oof)[0], axis=-1))
    # OOF names
    ds_valid_names = get_dataset(VALID_FILENAMES, labeled=False, ordered=True)
    oof_names.append(np.array([img_name.numpy().decode('utf-8') for img, img_name in iter(ds_valid_names.unbatch())]))
# Out:
# FOLD: 1
# TRAIN: [ 0  2  3  4  5  7  9 10 11 12 13 14] VALID: [1 6 8]
# Downloading data from https://github.com/qubvel/efficientnet/releases/download/v0.0.1/efficientnet-b5_noisy-student_notop.h5
# 115261440/115255328 [==============================] - 1s 0us/step
#
# EPOCH 1/33
# time: 202.4s loss: 1.4169 accuracy_aux_2: 0.6806 accuracy_aux: 0.8068 accuracy: 0.6320 val_loss: 0.7932 val_accuracy_aux_2: 0.8816 val_accuracy_aux: 0.8909 val_accuracy: 0.7898 lr: 2.667e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 2/33
# time: 59.1s loss: 1.1846 accuracy_aux_2: 0.9053 accuracy_aux: 0.8984 accuracy: 0.8152 val_loss: 0.6498 val_accuracy_aux_2: 0.9354 val_accuracy_aux: 0.9202 val_accuracy: 0.8674 lr: 5.334e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 3/33
# time: 60.1s loss: 1.1371 accuracy_aux_2: 0.9324 accuracy_aux: 0.9153 accuracy: 0.8520 val_loss: 0.6085 val_accuracy_aux_2: 0.9503 val_accuracy_aux: 0.9328 val_accuracy: 0.8771 lr: 8e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 4/33
# time: 59.9s loss: 1.1230 accuracy_aux_2: 0.9373 accuracy_aux: 0.9254 accuracy: 0.8603 val_loss: 0.5931 val_accuracy_aux_2: 0.9503 val_accuracy_aux: 0.9339 val_accuracy: 0.8797 lr: 7.804e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 5/33
# time: 60.2s loss: 1.1064 accuracy_aux_2: 0.9434 accuracy_aux: 0.9295 accuracy: 0.8714 val_loss: 0.5829 val_accuracy_aux_2: 0.9510 val_accuracy_aux: 0.9380 val_accuracy: 0.8812 lr: 7.236e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 6/33
# time: 60.5s loss: 1.0981 accuracy_aux_2: 0.9469 accuracy_aux: 0.9319 accuracy: 0.8766 val_loss: 0.6031 val_accuracy_aux_2: 0.9538 val_accuracy_aux: 0.9342 val_accuracy: 0.8847 lr: 6.351e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 7/33
# time: 61.1s loss: 1.0885 accuracy_aux_2: 0.9501 accuracy_aux: 0.9358 accuracy: 0.8840 val_loss: 0.5924 val_accuracy_aux_2: 0.9538 val_accuracy_aux: 0.9389 val_accuracy: 0.8916 lr: 5.236e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 8/33
# time: 61.0s loss: 1.0824 accuracy_aux_2: 0.9512 accuracy_aux: 0.9377 accuracy: 0.8882 val_loss: 0.5689 val_accuracy_aux_2: 0.9579 val_accuracy_aux: 0.9394 val_accuracy: 0.8949 lr: 4e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 9/33
# time: 61.2s loss: 1.0751 accuracy_aux_2: 0.9539 accuracy_aux: 0.9414 accuracy: 0.8930 val_loss: 0.5722 val_accuracy_aux_2: 0.9571 val_accuracy_aux: 0.9394 val_accuracy: 0.8932 lr: 2.764e-05
#
# EPOCH 10/33
# time: 61.6s loss: 1.0708 accuracy_aux_2: 0.9568 accuracy_aux: 0.9410 accuracy: 0.8970 val_loss: 0.5714 val_accuracy_aux_2: 0.9555 val_accuracy_aux: 0.9406 val_accuracy: 0.8918 lr: 1.649e-05
#
# EPOCH 11/33
# time: 61.6s loss: 1.0689 accuracy_aux_2: 0.9556 accuracy_aux: 0.9425 accuracy: 0.8983 val_loss: 0.5605 val_accuracy_aux_2: 0.9569 val_accuracy_aux: 0.9406 val_accuracy: 0.8954 lr: 7.639e-06
# Saved model weights at "model_0.h5"
#
# EPOCH 12/33
# time: 62.0s loss: 1.0648 accuracy_aux_2: 0.9576 accuracy_aux: 0.9435 accuracy: 0.9003 val_loss: 0.5566 val_accuracy_aux_2: 0.9586 val_accuracy_aux: 0.9401 val_accuracy: 0.8942 lr: 1.958e-06
#
# EPOCH 13/33
# time: 61.5s loss: 1.0639 accuracy_aux_2: 0.9586 accuracy_aux: 0.9429 accuracy: 0.9008 val_loss: 0.5548 val_accuracy_aux_2: 0.9593 val_accuracy_aux: 0.9392 val_accuracy: 0.8946 lr: 8e-05
#
# EPOCH 14/33
# time: 62.0s loss: 1.0805 accuracy_aux_2: 0.9532 accuracy_aux: 0.9393 accuracy: 0.8905 val_loss: 0.5694 val_accuracy_aux_2: 0.9555 val_accuracy_aux: 0.9415 val_accuracy: 0.8894 lr: 7.804e-05
#
# EPOCH 15/33
# time: 61.2s loss: 1.0763 accuracy_aux_2: 0.9551 accuracy_aux: 0.9391 accuracy: 0.8933 val_loss: 0.5814 val_accuracy_aux_2: 0.9576 val_accuracy_aux: 0.9411 val_accuracy: 0.8920 lr: 7.236e-05
#
# EPOCH 16/33
# time: 61.0s loss: 1.0767 accuracy_aux_2: 0.9555 accuracy_aux: 0.9398 accuracy: 0.8918 val_loss: 0.5688 val_accuracy_aux_2: 0.9581 val_accuracy_aux: 0.9366 val_accuracy: 0.8890 lr: 6.351e-05
#
# EPOCH 17/33
# time: 61.1s loss: 1.0698 accuracy_aux_2: 0.9554 accuracy_aux: 0.9439 accuracy: 0.8981 val_loss: 0.5611 val_accuracy_aux_2: 0.9538 val_accuracy_aux: 0.9418 val_accuracy: 0.8911 lr: 5.236e-05
#
# EPOCH 18/33
# time: 60.6s loss: 1.0655 accuracy_aux_2: 0.9573 accuracy_aux: 0.9446 accuracy: 0.8983 val_loss: 0.5625 val_accuracy_aux_2: 0.9560 val_accuracy_aux: 0.9384 val_accuracy: 0.8904 lr: 4e-05
#
# EPOCH 19/33
# time: 60.1s loss: 1.0597 accuracy_aux_2: 0.9597 accuracy_aux: 0.9462 accuracy: 0.9027 val_loss: 0.5622 val_accuracy_aux_2: 0.9567 val_accuracy_aux: 0.9408 val_accuracy: 0.8944 lr: 2.764e-05
#
# EPOCH 20/33
# time: 59.5s loss: 1.0572 accuracy_aux_2: 0.9596 accuracy_aux: 0.9478 accuracy: 0.9067 val_loss: 0.5652 val_accuracy_aux_2: 0.9571 val_accuracy_aux: 0.9411 val_accuracy: 0.8954 lr: 1.649e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 21/33
# time: 60.0s loss: 1.0559 accuracy_aux_2: 0.9599 accuracy_aux: 0.9473 accuracy: 0.9064 val_loss: 0.5562 val_accuracy_aux_2: 0.9579 val_accuracy_aux: 0.9415 val_accuracy: 0.8963 lr: 7.639e-06
# Saved model weights at "model_0.h5"
#
# EPOCH 22/33
# time: 59.5s loss: 1.0503 accuracy_aux_2: 0.9624 accuracy_aux: 0.9511 accuracy: 0.9107 val_loss: 0.5508 val_accuracy_aux_2: 0.9581 val_accuracy_aux: 0.9420 val_accuracy: 0.8970 lr: 1.958e-06
# Saved model weights at "model_0.h5"
#
# EPOCH 23/33
# time: 60.0s loss: 1.0501 accuracy_aux_2: 0.9610 accuracy_aux: 0.9498 accuracy: 0.9098 val_loss: 0.5497 val_accuracy_aux_2: 0.9595 val_accuracy_aux: 0.9413 val_accuracy: 0.8973 lr: 8e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 24/33
# time: 59.4s loss: 1.0678 accuracy_aux_2: 0.9569 accuracy_aux: 0.9437 accuracy: 0.8976 val_loss: 0.5716 val_accuracy_aux_2: 0.9524 val_accuracy_aux: 0.9413 val_accuracy: 0.8920 lr: 7.804e-05
#
# EPOCH 25/33
# time: 59.8s loss: 1.0649 accuracy_aux_2: 0.9566 accuracy_aux: 0.9452 accuracy: 0.8993 val_loss: 0.5559 val_accuracy_aux_2: 0.9571 val_accuracy_aux: 0.9415 val_accuracy: 0.8956 lr: 7.236e-05
#
# EPOCH 26/33
# time: 59.7s loss: 1.0643 accuracy_aux_2: 0.9583 accuracy_aux: 0.9465 accuracy: 0.9031 val_loss: 0.5698 val_accuracy_aux_2: 0.9588 val_accuracy_aux: 0.9392 val_accuracy: 0.8949 lr: 6.351e-05
#
# EPOCH 27/33
# time: 59.5s loss: 1.0605 accuracy_aux_2: 0.9599 accuracy_aux: 0.9473 accuracy: 0.9043 val_loss: 0.5723 val_accuracy_aux_2: 0.9588 val_accuracy_aux: 0.9429 val_accuracy: 0.8968 lr: 5.236e-05
#
# EPOCH 28/33
# time: 58.9s loss: 1.0565 accuracy_aux_2: 0.9603 accuracy_aux: 0.9477 accuracy: 0.9063 val_loss: 0.5576 val_accuracy_aux_2: 0.9560 val_accuracy_aux: 0.9429 val_accuracy: 0.8930 lr: 4e-05
#
# EPOCH 29/33
# time: 59.8s loss: 1.0512 accuracy_aux_2: 0.9623 accuracy_aux: 0.9491 accuracy: 0.9116 val_loss: 0.5587 val_accuracy_aux_2: 0.9595 val_accuracy_aux: 0.9420 val_accuracy: 0.8949 lr: 2.764e-05
#
# EPOCH 30/33
# time: 60.2s loss: 1.0465 accuracy_aux_2: 0.9625 accuracy_aux: 0.9516 accuracy: 0.9141 val_loss: 0.5475 val_accuracy_aux_2: 0.9586 val_accuracy_aux: 0.9422 val_accuracy: 0.8965 lr: 1.649e-05
#
# EPOCH 31/33
# time: 59.2s loss: 1.0434 accuracy_aux_2: 0.9640 accuracy_aux: 0.9529 accuracy: 0.9174 val_loss: 0.5466 val_accuracy_aux_2: 0.9590 val_accuracy_aux: 0.9427 val_accuracy: 0.8977 lr: 7.639e-06
# Saved model weights at "model_0.h5"
#
# EPOCH 32/33
# time: 59.2s loss: 1.0425 accuracy_aux_2: 0.9653 accuracy_aux: 0.9523 accuracy: 0.9178 val_loss: 0.5529 val_accuracy_aux_2: 0.9583 val_accuracy_aux: 0.9429 val_accuracy: 0.8989 lr: 1.958e-06
# Saved model weights at "model_0.h5"
#
# EPOCH 33/33
# time: 59.8s loss: 1.0379 accuracy_aux_2: 0.9667 accuracy_aux: 0.9553 accuracy: 0.9214 val_loss: 0.5492 val_accuracy_aux_2: 0.9600 val_accuracy_aux: 0.9437 val_accuracy: 0.8980 lr: 8e-05
# #### FOLD 1 OOF Accuracy = 0.899
#
# FOLD: 2
# TRAIN: [ 0  1  2  3  5  6  7  8 10 11 12 13] VALID: [ 4  9 14]
#
# EPOCH 1/33
# time: 200.0s loss: 1.4101 accuracy_aux_2: 0.7081 accuracy_aux: 0.8570 accuracy: 0.6458 val_loss: 0.8152 val_accuracy_aux_2: 0.8956 val_accuracy_aux: 0.8797 val_accuracy: 0.8009 lr: 2.667e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 2/33
# time: 60.8s loss: 1.1854 accuracy_aux_2: 0.9039 accuracy_aux: 0.8969 accuracy: 0.8148 val_loss: 0.6470 val_accuracy_aux_2: 0.9344 val_accuracy_aux: 0.9006 val_accuracy: 0.8577 lr: 5.334e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 3/33
# time: 60.2s loss: 1.1404 accuracy_aux_2: 0.9291 accuracy_aux: 0.9154 accuracy: 0.8482 val_loss: 0.5972 val_accuracy_aux_2: 0.9510 val_accuracy_aux: 0.9285 val_accuracy: 0.8776 lr: 8e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 4/33
# time: 59.9s loss: 1.1222 accuracy_aux_2: 0.9376 accuracy_aux: 0.9215 accuracy: 0.8593 val_loss: 0.6054 val_accuracy_aux_2: 0.9522 val_accuracy_aux: 0.9266 val_accuracy: 0.8828 lr: 7.804e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 5/33
# time: 62.0s loss: 1.1097 accuracy_aux_2: 0.9431 accuracy_aux: 0.9272 accuracy: 0.8685 val_loss: 0.5786 val_accuracy_aux_2: 0.9564 val_accuracy_aux: 0.9351 val_accuracy: 0.8875 lr: 7.236e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 6/33
# time: 62.2s loss: 1.0977 accuracy_aux_2: 0.9465 accuracy_aux: 0.9305 accuracy: 0.8754 val_loss: 0.5699 val_accuracy_aux_2: 0.9531 val_accuracy_aux: 0.9368 val_accuracy: 0.8857 lr: 6.351e-05
#
# EPOCH 7/33
# time: 62.7s loss: 1.0885 accuracy_aux_2: 0.9500 accuracy_aux: 0.9351 accuracy: 0.8830 val_loss: 0.5909 val_accuracy_aux_2: 0.9503 val_accuracy_aux: 0.9373 val_accuracy: 0.8821 lr: 5.236e-05
#
# EPOCH 8/33
# time: 62.7s loss: 1.0844 accuracy_aux_2: 0.9527 accuracy_aux: 0.9376 accuracy: 0.8878 val_loss: 0.5618 val_accuracy_aux_2: 0.9557 val_accuracy_aux: 0.9418 val_accuracy: 0.8892 lr: 4e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 9/33
# time: 59.5s loss: 1.0757 accuracy_aux_2: 0.9543 accuracy_aux: 0.9383 accuracy: 0.8919 val_loss: 0.5729 val_accuracy_aux_2: 0.9562 val_accuracy_aux: 0.9377 val_accuracy: 0.8909 lr: 2.764e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 10/33
# time: 60.7s loss: 1.0719 accuracy_aux_2: 0.9554 accuracy_aux: 0.9415 accuracy: 0.8947 val_loss: 0.5478 val_accuracy_aux_2: 0.9574 val_accuracy_aux: 0.9415 val_accuracy: 0.8942 lr: 1.649e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 11/33
# time: 61.5s loss: 1.0695 accuracy_aux_2: 0.9558 accuracy_aux: 0.9421 accuracy: 0.8947 val_loss: 0.5461 val_accuracy_aux_2: 0.9581 val_accuracy_aux: 0.9415 val_accuracy: 0.8970 lr: 7.639e-06
# Saved model weights at "model_1.h5"
#
# EPOCH 12/33
# time: 62.0s loss: 1.0655 accuracy_aux_2: 0.9581 accuracy_aux: 0.9432 accuracy: 0.8993 val_loss: 0.5494 val_accuracy_aux_2: 0.9576 val_accuracy_aux: 0.9420 val_accuracy: 0.8968 lr: 1.958e-06
#
# EPOCH 13/33
# time: 60.2s loss: 1.0646 accuracy_aux_2: 0.9586 accuracy_aux: 0.9446 accuracy: 0.8992 val_loss: 0.5470 val_accuracy_aux_2: 0.9586 val_accuracy_aux: 0.9427 val_accuracy: 0.8980 lr: 8e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 14/33
# time: 61.0s loss: 1.0821 accuracy_aux_2: 0.9520 accuracy_aux: 0.9387 accuracy: 0.8892 val_loss: 0.5672 val_accuracy_aux_2: 0.9571 val_accuracy_aux: 0.9387 val_accuracy: 0.8939 lr: 7.804e-05
#
# EPOCH 15/33
# time: 61.4s loss: 1.0789 accuracy_aux_2: 0.9545 accuracy_aux: 0.9398 accuracy: 0.8919 val_loss: 0.5638 val_accuracy_aux_2: 0.9529 val_accuracy_aux: 0.9387 val_accuracy: 0.8916 lr: 7.236e-05
#
# EPOCH 16/33
# time: 61.2s loss: 1.0785 accuracy_aux_2: 0.9537 accuracy_aux: 0.9398 accuracy: 0.8905 val_loss: 0.5687 val_accuracy_aux_2: 0.9581 val_accuracy_aux: 0.9411 val_accuracy: 0.8951 lr: 6.351e-05
#
# EPOCH 17/33
# time: 61.5s loss: 1.0700 accuracy_aux_2: 0.9562 accuracy_aux: 0.9432 accuracy: 0.8975 val_loss: 0.5586 val_accuracy_aux_2: 0.9571 val_accuracy_aux: 0.9422 val_accuracy: 0.8987 lr: 5.236e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 18/33
# time: 62.5s loss: 1.0674 accuracy_aux_2: 0.9570 accuracy_aux: 0.9442 accuracy: 0.8969 val_loss: 0.5476 val_accuracy_aux_2: 0.9588 val_accuracy_aux: 0.9434 val_accuracy: 0.8954 lr: 4e-05
#
# EPOCH 19/33
# time: 60.0s loss: 1.0602 accuracy_aux_2: 0.9585 accuracy_aux: 0.9467 accuracy: 0.9035 val_loss: 0.5602 val_accuracy_aux_2: 0.9588 val_accuracy_aux: 0.9437 val_accuracy: 0.8944 lr: 2.764e-05
#
# EPOCH 20/33
# time: 61.3s loss: 1.0588 accuracy_aux_2: 0.9576 accuracy_aux: 0.9467 accuracy: 0.9040 val_loss: 0.5510 val_accuracy_aux_2: 0.9581 val_accuracy_aux: 0.9434 val_accuracy: 0.8975 lr: 1.649e-05
#
# EPOCH 21/33
# time: 62.8s loss: 1.0551 accuracy_aux_2: 0.9607 accuracy_aux: 0.9476 accuracy: 0.9078 val_loss: 0.5442 val_accuracy_aux_2: 0.9569 val_accuracy_aux: 0.9437 val_accuracy: 0.8982 lr: 7.639e-06
#
# EPOCH 22/33
# time: 60.5s loss: 1.0527 accuracy_aux_2: 0.9609 accuracy_aux: 0.9489 accuracy: 0.9085 val_loss: 0.5466 val_accuracy_aux_2: 0.9581 val_accuracy_aux: 0.9434 val_accuracy: 0.8996 lr: 1.958e-06
# Saved model weights at "model_1.h5"
#
# EPOCH 23/33
# time: 61.5s loss: 1.0499 accuracy_aux_2: 0.9614 accuracy_aux: 0.9493 accuracy: 0.9102 val_loss: 0.5406 val_accuracy_aux_2: 0.9574 val_accuracy_aux: 0.9439 val_accuracy: 0.8989 lr: 8e-05
#
# EPOCH 24/33
# time: 60.3s loss: 1.0665 accuracy_aux_2: 0.9561 accuracy_aux: 0.9463 accuracy: 0.8994 val_loss: 0.5703 val_accuracy_aux_2: 0.9593 val_accuracy_aux: 0.9413 val_accuracy: 0.8961 lr: 7.804e-05
#
# EPOCH 25/33
# time: 59.5s loss: 1.0661 accuracy_aux_2: 0.9583 accuracy_aux: 0.9435 accuracy: 0.9005 val_loss: 0.5764 val_accuracy_aux_2: 0.9553 val_accuracy_aux: 0.9392 val_accuracy: 0.8897 lr: 7.236e-05
#
# EPOCH 26/33
# time: 59.6s loss: 1.0655 accuracy_aux_2: 0.9580 accuracy_aux: 0.9472 accuracy: 0.9009 val_loss: 0.5531 val_accuracy_aux_2: 0.9548 val_accuracy_aux: 0.9437 val_accuracy: 0.8925 lr: 6.351e-05
#
# EPOCH 27/33
# time: 59.1s loss: 1.0606 accuracy_aux_2: 0.9577 accuracy_aux: 0.9483 accuracy: 0.9055 val_loss: 0.5460 val_accuracy_aux_2: 0.9569 val_accuracy_aux: 0.9413 val_accuracy: 0.8982 lr: 5.236e-05
#
# EPOCH 28/33
# time: 59.0s loss: 1.0539 accuracy_aux_2: 0.9607 accuracy_aux: 0.9478 accuracy: 0.9080 val_loss: 0.5362 val_accuracy_aux_2: 0.9583 val_accuracy_aux: 0.9401 val_accuracy: 0.8961 lr: 4e-05
#
# EPOCH 29/33
# time: 59.1s loss: 1.0510 accuracy_aux_2: 0.9617 accuracy_aux: 0.9493 accuracy: 0.9110 val_loss: 0.5466 val_accuracy_aux_2: 0.9595 val_accuracy_aux: 0.9420 val_accuracy: 0.9001 lr: 2.764e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 30/33
# time: 58.7s loss: 1.0486 accuracy_aux_2: 0.9629 accuracy_aux: 0.9522 accuracy: 0.9120 val_loss: 0.5409 val_accuracy_aux_2: 0.9595 val_accuracy_aux: 0.9413 val_accuracy: 0.8982 lr: 1.649e-05
#
# EPOCH 31/33
# time: 58.9s loss: 1.0451 accuracy_aux_2: 0.9656 accuracy_aux: 0.9523 accuracy: 0.9159 val_loss: 0.5399 val_accuracy_aux_2: 0.9595 val_accuracy_aux: 0.9441 val_accuracy: 0.9018 lr: 7.639e-06
# Saved model weights at "model_1.h5"
#
# EPOCH 32/33
# time: 58.4s loss: 1.0426 accuracy_aux_2: 0.9634 accuracy_aux: 0.9547 accuracy: 0.9171 val_loss: 0.5402 val_accuracy_aux_2: 0.9605 val_accuracy_aux: 0.9437 val_accuracy: 0.8999 lr: 1.958e-06
#
# EPOCH 33/33
# time: 58.9s loss: 1.0413 accuracy_aux_2: 0.9648 accuracy_aux: 0.9526 accuracy: 0.9172 val_loss: 0.5377 val_accuracy_aux_2: 0.9598 val_accuracy_aux: 0.9429 val_accuracy: 0.8999 lr: 8e-05
# #### FOLD 2 OOF Accuracy = 0.902
#
# FOLD: 3
# TRAIN: [ 0  1  3  4  5  6  7  8  9 11 12 14] VALID: [ 2 10 13]
#
# EPOCH 1/33
# time: 181.1s loss: 1.3896 accuracy_aux_2: 0.7044 accuracy_aux: 0.8131 accuracy: 0.6628 val_loss: 0.7552 val_accuracy_aux_2: 0.8994 val_accuracy_aux: 0.8793 val_accuracy: 0.8161 lr: 2.667e-05
# Saved model weights at "model_2.h5"
#
# EPOCH 2/33
# time: 58.3s loss: 1.1830 accuracy_aux_2: 0.9074 accuracy_aux: 0.8934 accuracy: 0.8170 val_loss: 0.6283 val_accuracy_aux_2: 0.9283 val_accuracy_aux: 0.9091 val_accuracy: 0.8580 lr: 5.334e-05
# Saved model weights at "model_2.h5"
#
# EPOCH 3/33
# time: 58.2s loss: 1.1385 accuracy_aux_2: 0.9309 accuracy_aux: 0.9175 accuracy: 0.8487 val_loss: 0.5932 val_accuracy_aux_2: 0.9427 val_accuracy_aux: 0.9197 val_accuracy: 0.8686 lr: 8e-05
# Saved model weights at "model_2.h5"
#
# EPOCH 4/33
# time: 57.8s loss: 1.1215 accuracy_aux_2: 0.9381 accuracy_aux: 0.9244 accuracy: 0.8607 val_loss: 0.5891 val_accuracy_aux_2: 0.9503 val_accuracy_aux: 0.9330 val_accuracy: 0.8828 lr: 7.804e-05
# Saved model weights at "model_2.h5"
#
# EPOCH 5/33
# time: 58.3s loss: 1.1095 accuracy_aux_2: 0.9421 accuracy_aux: 0.9279 accuracy: 0.8698 val_loss: 0.6003 val_accuracy_aux_2: 0.9420 val_accuracy_aux: 0.9323 val_accuracy: 0.8748 lr: 7.236e-05
#
# EPOCH 6/33
# time: 60.5s loss: 1.1010 accuracy_aux_2: 0.9456 accuracy_aux: 0.9317 accuracy: 0.8744 val_loss: 0.5544 val_accuracy_aux_2: 0.9515 val_accuracy_aux: 0.9396 val_accuracy: 0.8923 lr: 6.351e-05
# Saved model weights at "model_2.h5"
#
# EPOCH 7/33
# time: 57.8s loss: 1.0904 accuracy_aux_2: 0.9487 accuracy_aux: 0.9373 accuracy: 0.8825 val_loss: 0.5763 val_accuracy_aux_2: 0.9529 val_accuracy_aux: 0.9366 val_accuracy: 0.8883 lr: 5.236e-05
#
# EPOCH 8/33
# time: 57.9s loss: 1.0840 accuracy_aux_2: 0.9513 accuracy_aux: 0.9365 accuracy: 0.8865 val_loss: 0.5496 val_accuracy_aux_2: 0.9576 val_accuracy_aux: 0.9413 val_accuracy: 0.8973 lr: 4e-05
# Saved model weights at "model_2.h5"
#
# EPOCH 9/33
# time: 56.9s loss: 1.0776 accuracy_aux_2: 0.9539 accuracy_aux: 0.9388 accuracy: 0.8914 val_loss: 0.5603 val_accuracy_aux_2: 0.9562 val_accuracy_aux: 0.9422 val_accuracy: 0.8977 lr: 2.764e-05
# Saved model weights at "model_2.h5"
#
# EPOCH 10/33
# time: 56.7s loss: 1.0744 accuracy_aux_2: 0.9556 accuracy_aux: 0.9395 accuracy: 0.8936 val_loss: 0.5579 val_accuracy_aux_2: 0.9550 val_accuracy_aux: 0.9411 val_accuracy: 0.8968 lr: 1.649e-05
#
# EPOCH 11/33
# time: 57.8s loss: 1.0679 accuracy_aux_2: 0.9572 accuracy_aux: 0.9406 accuracy: 0.8994 val_loss: 0.5484 val_accuracy_aux_2: 0.9579 val_accuracy_aux: 0.9437 val_accuracy: 0.8982 lr: 7.639e-06
# Saved model weights at "model_2.h5"
#
# EPOCH 12/33
# time: 57.2s loss: 1.0655 accuracy_aux_2: 0.9569 accuracy_aux: 0.9425 accuracy: 0.8989 val_loss: 0.5503 val_accuracy_aux_2: 0.9574 val_accuracy_aux: 0.9413 val_accuracy: 0.9001 lr: 1.958e-06
# Saved model weights at "model_2.h5"
#
# EPOCH 13/33
# time: 57.8s loss: 1.0646 accuracy_aux_2: 0.9595 accuracy_aux: 0.9438 accuracy: 0.9012 val_loss: 0.5502 val_accuracy_aux_2: 0.9586 val_accuracy_aux: 0.9415 val_accuracy: 0.8996 lr: 8e-05
#
# EPOCH 14/33
# time: 57.9s loss: 1.0843 accuracy_aux_2: 0.9498 accuracy_aux: 0.9390 accuracy: 0.8872 val_loss: 0.5666 val_accuracy_aux_2: 0.9576 val_accuracy_aux: 0.9361 val_accuracy: 0.8932 lr: 7.804e-05
#
# EPOCH 15/33
# time: 56.8s loss: 1.0795 accuracy_aux_2: 0.9512 accuracy_aux: 0.9397 accuracy: 0.8902 val_loss: 0.5563 val_accuracy_aux_2: 0.9541 val_accuracy_aux: 0.9401 val_accuracy: 0.8949 lr: 7.236e-05
#
# EPOCH 16/33
# time: 57.4s loss: 1.0760 accuracy_aux_2: 0.9550 accuracy_aux: 0.9402 accuracy: 0.8943 val_loss: 0.5564 val_accuracy_aux_2: 0.9590 val_accuracy_aux: 0.9396 val_accuracy: 0.8968 lr: 6.351e-05
#
# EPOCH 17/33
# time: 57.3s loss: 1.0701 accuracy_aux_2: 0.9563 accuracy_aux: 0.9446 accuracy: 0.8974 val_loss: 0.5573 val_accuracy_aux_2: 0.9569 val_accuracy_aux: 0.9444 val_accuracy: 0.8982 lr: 5.236e-05
#
# EPOCH 18/33
# time: 57.7s loss: 1.0679 accuracy_aux_2: 0.9555 accuracy_aux: 0.9439 accuracy: 0.8984 val_loss: 0.5557 val_accuracy_aux_2: 0.9579 val_accuracy_aux: 0.9366 val_accuracy: 0.8956 lr: 4e-05
#
# EPOCH 19/33
# time: 56.5s loss: 1.0595 accuracy_aux_2: 0.9593 accuracy_aux: 0.9464 accuracy: 0.9056 val_loss: 0.5481 val_accuracy_aux_2: 0.9581 val_accuracy_aux: 0.9432 val_accuracy: 0.9010 lr: 2.764e-05
# Saved model weights at "model_2.h5"
#
# EPOCH 20/33
# time: 55.9s loss: 1.0592 accuracy_aux_2: 0.9583 accuracy_aux: 0.9467 accuracy: 0.9058 val_loss: 0.5515 val_accuracy_aux_2: 0.9579 val_accuracy_aux: 0.9427 val_accuracy: 0.8973 lr: 1.649e-05
#
# EPOCH 21/33
# time: 56.4s loss: 1.0547 accuracy_aux_2: 0.9609 accuracy_aux: 0.9471 accuracy: 0.9080 val_loss: 0.5478 val_accuracy_aux_2: 0.9583 val_accuracy_aux: 0.9406 val_accuracy: 0.9003 lr: 7.639e-06
#
# EPOCH 22/33
# time: 58.8s loss: 1.0500 accuracy_aux_2: 0.9631 accuracy_aux: 0.9497 accuracy: 0.9117 val_loss: 0.5455 val_accuracy_aux_2: 0.9583 val_accuracy_aux: 0.9432 val_accuracy: 0.9008 lr: 1.958e-06
#
# EPOCH 23/33
# time: 56.0s loss: 1.0526 accuracy_aux_2: 0.9603 accuracy_aux: 0.9479 accuracy: 0.9098 val_loss: 0.5468 val_accuracy_aux_2: 0.9595 val_accuracy_aux: 0.9425 val_accuracy: 0.9006 lr: 8e-05
#
# EPOCH 24/33
# time: 56.7s loss: 1.0693 accuracy_aux_2: 0.9556 accuracy_aux: 0.9449 accuracy: 0.8982 val_loss: 0.5625 val_accuracy_aux_2: 0.9557 val_accuracy_aux: 0.9406 val_accuracy: 0.8965 lr: 7.804e-05
#
# EPOCH 25/33
# time: 57.0s loss: 1.0633 accuracy_aux_2: 0.9580 accuracy_aux: 0.9482 accuracy: 0.9022 val_loss: 0.5739 val_accuracy_aux_2: 0.9553 val_accuracy_aux: 0.9387 val_accuracy: 0.8847 lr: 7.236e-05
#
# EPOCH 26/33
# time: 56.8s loss: 1.0645 accuracy_aux_2: 0.9572 accuracy_aux: 0.9449 accuracy: 0.9012 val_loss: 0.5731 val_accuracy_aux_2: 0.9574 val_accuracy_aux: 0.9422 val_accuracy: 0.8920 lr: 6.351e-05
#
# EPOCH 27/33
# time: 56.9s loss: 1.0583 accuracy_aux_2: 0.9593 accuracy_aux: 0.9472 accuracy: 0.9061 val_loss: 0.5582 val_accuracy_aux_2: 0.9586 val_accuracy_aux: 0.9439 val_accuracy: 0.9006 lr: 5.236e-05
#
# EPOCH 28/33
# time: 56.7s loss: 1.0549 accuracy_aux_2: 0.9590 accuracy_aux: 0.9487 accuracy: 0.9078 val_loss: 0.5626 val_accuracy_aux_2: 0.9569 val_accuracy_aux: 0.9453 val_accuracy: 0.8965 lr: 4e-05
#
# EPOCH 29/33
# time: 59.4s loss: 1.0518 accuracy_aux_2: 0.9615 accuracy_aux: 0.9500 accuracy: 0.9122 val_loss: 0.5595 val_accuracy_aux_2: 0.9579 val_accuracy_aux: 0.9413 val_accuracy: 0.8989 lr: 2.764e-05
# Epoch 00028: early stopping
# #### FOLD 3 OOF Accuracy = 0.901
#
# FOLD: 4
# TRAIN: [ 0  1  2  4  5  6  8  9 10 12 13 14] VALID: [ 3  7 11]
#
# EPOCH 1/33
# time: 200.2s loss: 1.4079 accuracy_aux_2: 0.6812 accuracy_aux: 0.7668 accuracy: 0.6434 val_loss: 0.8057 val_accuracy_aux_2: 0.8873 val_accuracy_aux: 0.8733 val_accuracy: 0.8097 lr: 2.667e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 2/33
# time: 59.6s loss: 1.1846 accuracy_aux_2: 0.9048 accuracy_aux: 0.8909 accuracy: 0.8152 val_loss: 0.6446 val_accuracy_aux_2: 0.9337 val_accuracy_aux: 0.9079 val_accuracy: 0.8523 lr: 5.334e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 3/33
# time: 58.3s loss: 1.1407 accuracy_aux_2: 0.9294 accuracy_aux: 0.9140 accuracy: 0.8492 val_loss: 0.6302 val_accuracy_aux_2: 0.9441 val_accuracy_aux: 0.9304 val_accuracy: 0.8759 lr: 8e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 4/33
# time: 57.1s loss: 1.1202 accuracy_aux_2: 0.9395 accuracy_aux: 0.9260 accuracy: 0.8619 val_loss: 0.5994 val_accuracy_aux_2: 0.9463 val_accuracy_aux: 0.9302 val_accuracy: 0.8778 lr: 7.804e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 5/33
# time: 57.2s loss: 1.1064 accuracy_aux_2: 0.9446 accuracy_aux: 0.9322 accuracy: 0.8732 val_loss: 0.6081 val_accuracy_aux_2: 0.9486 val_accuracy_aux: 0.9280 val_accuracy: 0.8788 lr: 7.236e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 6/33
# time: 57.1s loss: 1.0978 accuracy_aux_2: 0.9478 accuracy_aux: 0.9322 accuracy: 0.8765 val_loss: 0.6017 val_accuracy_aux_2: 0.9484 val_accuracy_aux: 0.9342 val_accuracy: 0.8816 lr: 6.351e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 7/33
# time: 57.0s loss: 1.0895 accuracy_aux_2: 0.9504 accuracy_aux: 0.9371 accuracy: 0.8841 val_loss: 0.5881 val_accuracy_aux_2: 0.9496 val_accuracy_aux: 0.9337 val_accuracy: 0.8774 lr: 5.236e-05
#
# EPOCH 8/33
# time: 57.4s loss: 1.0828 accuracy_aux_2: 0.9531 accuracy_aux: 0.9380 accuracy: 0.8875 val_loss: 0.5897 val_accuracy_aux_2: 0.9498 val_accuracy_aux: 0.9342 val_accuracy: 0.8845 lr: 4e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 9/33
# time: 57.2s loss: 1.0768 accuracy_aux_2: 0.9543 accuracy_aux: 0.9405 accuracy: 0.8920 val_loss: 0.5560 val_accuracy_aux_2: 0.9519 val_accuracy_aux: 0.9394 val_accuracy: 0.8913 lr: 2.764e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 10/33
# time: 57.2s loss: 1.0712 accuracy_aux_2: 0.9559 accuracy_aux: 0.9424 accuracy: 0.8974 val_loss: 0.5627 val_accuracy_aux_2: 0.9524 val_accuracy_aux: 0.9377 val_accuracy: 0.8911 lr: 1.649e-05
#
# EPOCH 11/33
# time: 56.8s loss: 1.0694 accuracy_aux_2: 0.9563 accuracy_aux: 0.9428 accuracy: 0.8967 val_loss: 0.5698 val_accuracy_aux_2: 0.9522 val_accuracy_aux: 0.9411 val_accuracy: 0.8930 lr: 7.639e-06
# Saved model weights at "model_3.h5"
#
# EPOCH 12/33
# time: 56.4s loss: 1.0641 accuracy_aux_2: 0.9580 accuracy_aux: 0.9448 accuracy: 0.9016 val_loss: 0.5610 val_accuracy_aux_2: 0.9538 val_accuracy_aux: 0.9399 val_accuracy: 0.8928 lr: 1.958e-06
#
# EPOCH 13/33
# time: 57.5s loss: 1.0639 accuracy_aux_2: 0.9591 accuracy_aux: 0.9465 accuracy: 0.9034 val_loss: 0.5598 val_accuracy_aux_2: 0.9536 val_accuracy_aux: 0.9406 val_accuracy: 0.8946 lr: 8e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 14/33
# time: 58.2s loss: 1.0818 accuracy_aux_2: 0.9521 accuracy_aux: 0.9395 accuracy: 0.8893 val_loss: 0.5993 val_accuracy_aux_2: 0.9508 val_accuracy_aux: 0.9363 val_accuracy: 0.8840 lr: 7.804e-05
#
# EPOCH 15/33
# time: 58.1s loss: 1.0817 accuracy_aux_2: 0.9528 accuracy_aux: 0.9392 accuracy: 0.8880 val_loss: 0.5911 val_accuracy_aux_2: 0.9444 val_accuracy_aux: 0.9403 val_accuracy: 0.8809 lr: 7.236e-05
#
# EPOCH 16/33
# time: 57.2s loss: 1.0737 accuracy_aux_2: 0.9535 accuracy_aux: 0.9424 accuracy: 0.8930 val_loss: 0.5625 val_accuracy_aux_2: 0.9517 val_accuracy_aux: 0.9403 val_accuracy: 0.8902 lr: 6.351e-05
#
# EPOCH 17/33
# time: 56.8s loss: 1.0688 accuracy_aux_2: 0.9545 accuracy_aux: 0.9436 accuracy: 0.8978 val_loss: 0.5786 val_accuracy_aux_2: 0.9505 val_accuracy_aux: 0.9406 val_accuracy: 0.8897 lr: 5.236e-05
#
# EPOCH 18/33
# time: 57.4s loss: 1.0660 accuracy_aux_2: 0.9574 accuracy_aux: 0.9446 accuracy: 0.8991 val_loss: 0.5731 val_accuracy_aux_2: 0.9524 val_accuracy_aux: 0.9387 val_accuracy: 0.8861 lr: 4e-05
#
# EPOCH 19/33
# time: 57.1s loss: 1.0622 accuracy_aux_2: 0.9579 accuracy_aux: 0.9457 accuracy: 0.9019 val_loss: 0.5668 val_accuracy_aux_2: 0.9515 val_accuracy_aux: 0.9401 val_accuracy: 0.8911 lr: 2.764e-05
#
# EPOCH 20/33
# time: 56.9s loss: 1.0581 accuracy_aux_2: 0.9612 accuracy_aux: 0.9473 accuracy: 0.9065 val_loss: 0.5686 val_accuracy_aux_2: 0.9505 val_accuracy_aux: 0.9403 val_accuracy: 0.8902 lr: 1.649e-05
#
# EPOCH 21/33
# time: 57.1s loss: 1.0526 accuracy_aux_2: 0.9614 accuracy_aux: 0.9504 accuracy: 0.9081 val_loss: 0.5619 val_accuracy_aux_2: 0.9534 val_accuracy_aux: 0.9415 val_accuracy: 0.8932 lr: 7.639e-06
#
# EPOCH 22/33
# time: 58.0s loss: 1.0517 accuracy_aux_2: 0.9620 accuracy_aux: 0.9503 accuracy: 0.9115 val_loss: 0.5617 val_accuracy_aux_2: 0.9529 val_accuracy_aux: 0.9429 val_accuracy: 0.8930 lr: 1.958e-06
#
# EPOCH 23/33
# time: 58.9s loss: 1.0506 accuracy_aux_2: 0.9625 accuracy_aux: 0.9511 accuracy: 0.9126 val_loss: 0.5611 val_accuracy_aux_2: 0.9519 val_accuracy_aux: 0.9427 val_accuracy: 0.8939 lr: 8e-05
# Epoch 00022: early stopping
# #### FOLD 4 OOF Accuracy = 0.895
#
# FOLD: 5
# TRAIN: [ 1  2  3  4  6  7  8  9 10 11 13 14] VALID: [ 0  5 12]
#
# EPOCH 1/33
# time: 177.7s loss: 1.4046 accuracy_aux_2: 0.7128 accuracy_aux: 0.7808 accuracy: 0.6482 val_loss: 0.7876 val_accuracy_aux_2: 0.8956 val_accuracy_aux: 0.8759 val_accuracy: 0.8037 lr: 2.667e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 2/33
# time: 55.5s loss: 1.1843 accuracy_aux_2: 0.9065 accuracy_aux: 0.8937 accuracy: 0.8141 val_loss: 0.6327 val_accuracy_aux_2: 0.9297 val_accuracy_aux: 0.9112 val_accuracy: 0.8511 lr: 5.334e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 3/33
# time: 56.3s loss: 1.1384 accuracy_aux_2: 0.9301 accuracy_aux: 0.9151 accuracy: 0.8494 val_loss: 0.6243 val_accuracy_aux_2: 0.9297 val_accuracy_aux: 0.9216 val_accuracy: 0.8570 lr: 8e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 4/33
# time: 56.3s loss: 1.1221 accuracy_aux_2: 0.9382 accuracy_aux: 0.9233 accuracy: 0.8594 val_loss: 0.6082 val_accuracy_aux_2: 0.9474 val_accuracy_aux: 0.9292 val_accuracy: 0.8795 lr: 7.804e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 5/33
# time: 57.6s loss: 1.1092 accuracy_aux_2: 0.9429 accuracy_aux: 0.9285 accuracy: 0.8701 val_loss: 0.5904 val_accuracy_aux_2: 0.9519 val_accuracy_aux: 0.9325 val_accuracy: 0.8797 lr: 7.236e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 6/33
# time: 56.7s loss: 1.0969 accuracy_aux_2: 0.9480 accuracy_aux: 0.9330 accuracy: 0.8799 val_loss: 0.5853 val_accuracy_aux_2: 0.9508 val_accuracy_aux: 0.9299 val_accuracy: 0.8788 lr: 6.351e-05
#
# EPOCH 7/33
# time: 56.4s loss: 1.0910 accuracy_aux_2: 0.9488 accuracy_aux: 0.9347 accuracy: 0.8812 val_loss: 0.5729 val_accuracy_aux_2: 0.9536 val_accuracy_aux: 0.9380 val_accuracy: 0.8930 lr: 5.236e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 8/33
# time: 56.8s loss: 1.0828 accuracy_aux_2: 0.9527 accuracy_aux: 0.9375 accuracy: 0.8872 val_loss: 0.5535 val_accuracy_aux_2: 0.9548 val_accuracy_aux: 0.9370 val_accuracy: 0.8932 lr: 4e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 9/33
# time: 56.3s loss: 1.0798 accuracy_aux_2: 0.9527 accuracy_aux: 0.9394 accuracy: 0.8903 val_loss: 0.5703 val_accuracy_aux_2: 0.9538 val_accuracy_aux: 0.9366 val_accuracy: 0.8906 lr: 2.764e-05
#
# EPOCH 10/33
# time: 55.3s loss: 1.0738 accuracy_aux_2: 0.9544 accuracy_aux: 0.9402 accuracy: 0.8934 val_loss: 0.5665 val_accuracy_aux_2: 0.9564 val_accuracy_aux: 0.9363 val_accuracy: 0.8939 lr: 1.649e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 11/33
# time: 56.9s loss: 1.0709 accuracy_aux_2: 0.9560 accuracy_aux: 0.9422 accuracy: 0.8961 val_loss: 0.5554 val_accuracy_aux_2: 0.9567 val_accuracy_aux: 0.9403 val_accuracy: 0.8989 lr: 7.639e-06
# Saved model weights at "model_4.h5"
#
# EPOCH 12/33
# time: 57.1s loss: 1.0658 accuracy_aux_2: 0.9573 accuracy_aux: 0.9426 accuracy: 0.8982 val_loss: 0.5511 val_accuracy_aux_2: 0.9564 val_accuracy_aux: 0.9411 val_accuracy: 0.9001 lr: 1.958e-06
# Saved model weights at "model_4.h5"
#
# EPOCH 13/33
# time: 57.5s loss: 1.0672 accuracy_aux_2: 0.9555 accuracy_aux: 0.9444 accuracy: 0.9002 val_loss: 0.5510 val_accuracy_aux_2: 0.9555 val_accuracy_aux: 0.9420 val_accuracy: 0.9008 lr: 8e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 14/33
# time: 58.1s loss: 1.0813 accuracy_aux_2: 0.9512 accuracy_aux: 0.9404 accuracy: 0.8879 val_loss: 0.5653 val_accuracy_aux_2: 0.9579 val_accuracy_aux: 0.9427 val_accuracy: 0.8958 lr: 7.804e-05
#
# EPOCH 15/33
# time: 55.7s loss: 1.0810 accuracy_aux_2: 0.9533 accuracy_aux: 0.9390 accuracy: 0.8907 val_loss: 0.5442 val_accuracy_aux_2: 0.9555 val_accuracy_aux: 0.9406 val_accuracy: 0.8946 lr: 7.236e-05
#
# EPOCH 16/33
# time: 55.9s loss: 1.0768 accuracy_aux_2: 0.9518 accuracy_aux: 0.9395 accuracy: 0.8926 val_loss: 0.5703 val_accuracy_aux_2: 0.9524 val_accuracy_aux: 0.9418 val_accuracy: 0.8913 lr: 6.351e-05
#
# EPOCH 17/33
# time: 55.6s loss: 1.0729 accuracy_aux_2: 0.9544 accuracy_aux: 0.9431 accuracy: 0.8943 val_loss: 0.5704 val_accuracy_aux_2: 0.9553 val_accuracy_aux: 0.9403 val_accuracy: 0.8918 lr: 5.236e-05
#
# EPOCH 18/33
# time: 56.6s loss: 1.0697 accuracy_aux_2: 0.9562 accuracy_aux: 0.9429 accuracy: 0.8986 val_loss: 0.5473 val_accuracy_aux_2: 0.9574 val_accuracy_aux: 0.9411 val_accuracy: 0.8968 lr: 4e-05
#
# EPOCH 19/33
# time: 55.6s loss: 1.0634 accuracy_aux_2: 0.9585 accuracy_aux: 0.9450 accuracy: 0.9019 val_loss: 0.5437 val_accuracy_aux_2: 0.9581 val_accuracy_aux: 0.9451 val_accuracy: 0.9008 lr: 2.764e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 20/33
# time: 56.5s loss: 1.0611 accuracy_aux_2: 0.9594 accuracy_aux: 0.9459 accuracy: 0.9041 val_loss: 0.5426 val_accuracy_aux_2: 0.9590 val_accuracy_aux: 0.9455 val_accuracy: 0.9027 lr: 1.649e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 21/33
# time: 55.4s loss: 1.0567 accuracy_aux_2: 0.9607 accuracy_aux: 0.9472 accuracy: 0.9066 val_loss: 0.5430 val_accuracy_aux_2: 0.9600 val_accuracy_aux: 0.9434 val_accuracy: 0.9044 lr: 7.639e-06
# Saved model weights at "model_4.h5"
#
# EPOCH 22/33
# time: 54.7s loss: 1.0547 accuracy_aux_2: 0.9603 accuracy_aux: 0.9483 accuracy: 0.9077 val_loss: 0.5380 val_accuracy_aux_2: 0.9602 val_accuracy_aux: 0.9467 val_accuracy: 0.9041 lr: 1.958e-06
#
# EPOCH 23/33
# time: 55.6s loss: 1.0529 accuracy_aux_2: 0.9616 accuracy_aux: 0.9482 accuracy: 0.9101 val_loss: 0.5409 val_accuracy_aux_2: 0.9595 val_accuracy_aux: 0.9448 val_accuracy: 0.9032 lr: 8e-05
#
# EPOCH 24/33
# time: 54.7s loss: 1.0666 accuracy_aux_2: 0.9566 accuracy_aux: 0.9441 accuracy: 0.8986 val_loss: 0.5363 val_accuracy_aux_2: 0.9574 val_accuracy_aux: 0.9439 val_accuracy: 0.8946 lr: 7.804e-05
#
# EPOCH 25/33
# time: 55.5s loss: 1.0683 accuracy_aux_2: 0.9565 accuracy_aux: 0.9446 accuracy: 0.8996 val_loss: 0.5665 val_accuracy_aux_2: 0.9571 val_accuracy_aux: 0.9439 val_accuracy: 0.8973 lr: 7.236e-05
#
# EPOCH 26/33
# time: 55.2s loss: 1.0658 accuracy_aux_2: 0.9586 accuracy_aux: 0.9439 accuracy: 0.9020 val_loss: 0.5788 val_accuracy_aux_2: 0.9538 val_accuracy_aux: 0.9432 val_accuracy: 0.8961 lr: 6.351e-05
#
# EPOCH 27/33
# time: 55.6s loss: 1.0594 accuracy_aux_2: 0.9587 accuracy_aux: 0.9473 accuracy: 0.9059 val_loss: 0.5580 val_accuracy_aux_2: 0.9560 val_accuracy_aux: 0.9444 val_accuracy: 0.8944 lr: 5.236e-05
#
# EPOCH 28/33
# time: 55.3s loss: 1.0571 accuracy_aux_2: 0.9594 accuracy_aux: 0.9483 accuracy: 0.9074 val_loss: 0.5660 val_accuracy_aux_2: 0.9590 val_accuracy_aux: 0.9429 val_accuracy: 0.8977 lr: 4e-05
#
# EPOCH 29/33
# time: 55.6s loss: 1.0536 accuracy_aux_2: 0.9597 accuracy_aux: 0.9498 accuracy: 0.9087 val_loss: 0.5529 val_accuracy_aux_2: 0.9576 val_accuracy_aux: 0.9470 val_accuracy: 0.9010 lr: 2.764e-05
#
# EPOCH 30/33
# time: 55.0s loss: 1.0475 accuracy_aux_2: 0.9632 accuracy_aux: 0.9518 accuracy: 0.9141 val_loss: 0.5463 val_accuracy_aux_2: 0.9598 val_accuracy_aux: 0.9455 val_accuracy: 0.9020 lr: 1.649e-05
#
# EPOCH 31/33
# time: 55.3s loss: 1.0448 accuracy_aux_2: 0.9636 accuracy_aux: 0.9511 accuracy: 0.9154 val_loss: 0.5395 val_accuracy_aux_2: 0.9607 val_accuracy_aux: 0.9467 val_accuracy: 0.9027 lr: 7.639e-06
# Epoch 00030: early stopping
# #### FOLD 5 OOF Accuracy = 0.904

# %% [markdown]
# ## Model loss graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1
# FOLD: 2
# FOLD: 3
# FOLD: 4
# FOLD: 5

# %% [markdown]
# # Model evaluation

# %%
y_true = np.concatenate(oof_labels)
y_true = np.argmax(y_true, axis=-1)
y_pred = np.concatenate(oof_pred)
folds = np.concatenate(oof_folds)
names = np.concatenate(oof_names)

acc = accuracy_score(y_true, y_pred)
print(f'Overall OOF Accuracy = {acc:.3f}')

df_oof = pd.DataFrame({'image_id':names, 'fold':fold, 
                       'target':y_true, 'pred':y_pred})
df_oof.to_csv('oof.csv', index=False)
display(df_oof.head())

print(classification_report(y_true, y_pred, target_names=CLASSES))
# Out:
# Overall OOF Accuracy = 0.900
#          image_id  fold  target  pred
# 0  1000201771.jpg     4       3     3
# 1  1000837476.jpg     4       3     3
# 2  1001723730.jpg     4       4     0
# 3  1001749118.jpg     4       3     3
# 4  1008284502.jpg     4       3     3
#                               precision    recall  f1-score   support
#
#     Cassava Bacterial Blight       0.67      0.72      0.69      1086
# Cassava Brown Streak Disease       0.84      0.83      0.84      2189
#         Cassava Green Mottle       0.85      0.80      0.82      2386
#       Cassava Mosaic Disease       0.96      0.98      0.97     13158
#                      Healthy       0.79      0.73      0.76      2576
#
#                     accuracy                           0.90     21395
#                    macro avg       0.82      0.81      0.82     21395
#                 weighted avg       0.90      0.90      0.90     21395

# %% [markdown]
# # Confusion matrix

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 12))
cfn_matrix = confusion_matrix(y_true, y_pred, labels=range(len(CLASSES)))
cfn_matrix = (cfn_matrix.T / cfn_matrix.sum(axis=1)).T
df_cm = pd.DataFrame(cfn_matrix, index=CLASSES, columns=CLASSES)
ax = sns.heatmap(df_cm, cmap='Blues', annot=True, fmt='.2f', linewidths=.5).set_title('Train', fontsize=30)
plt.show()

# %% [markdown]
# # Visualize predictions

# %%
# train_dataset = get_dataset(TRAINING_FILENAMES, ordered=True)
# x_samp, y_samp = dataset_to_numpy_util(train_dataset, 18)
# y_samp = np.argmax(y_samp, axis=-1)

# x_samp_1, y_samp_1 = x_samp[:9,:,:,:], y_samp[:9]
# samp_preds_1 = model.predict(x_samp_1, batch_size=9)
# display_9_images_with_predictions(x_samp_1, samp_preds_1, y_samp_1)

# x_samp_2, y_samp_2 = x_samp[9:,:,:,:], y_samp[9:]
# samp_preds_2 = model.predict(x_samp_2, batch_size=9)
# display_9_images_with_predictions(x_samp_2, samp_preds_2, y_samp_2)
