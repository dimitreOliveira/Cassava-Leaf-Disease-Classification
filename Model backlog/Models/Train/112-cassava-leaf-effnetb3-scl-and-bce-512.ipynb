# %% [markdown]
# ## Dependencies

# %%
# !pip install --quiet efficientnet
# Out:
# WARNING: You are using pip version 21.0; however, version 21.0.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
import warnings, time
from kaggle_datasets import KaggleDatasets
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras import optimizers, Sequential, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import efficientnet.tfkeras as efn
from cassava_scripts import *
from scripts_step_lr_schedulers import *
import tensorflow_addons as tfa


seed = 0
seed_everything(seed)
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Hardware configuration

# %%
# TPU or GPU detection
# Detect hardware, return appropriate distribution strategy
strategy, tpu = set_up_strategy()

AUTO = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Model parameters

# %%
BATCH_SIZE = 8 * REPLICAS
LEARNING_RATE = 1e-5 * REPLICAS
EPOCHS = 33
HEIGHT = 512
WIDTH = 512
HEIGHT_DT = 512
WIDTH_DT = 512
CHANNELS = 3
N_CLASSES = 5
N_FOLDS = 5
FOLDS_USED = 1
ES_PATIENCE = 10

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/cassava-leaf-disease-classification/'
train = pd.read_csv(f'{database_base_path}train.csv')
print(f'Train samples: {len(train)}')

GCS_PATH = KaggleDatasets().get_gcs_path(f'cassava-leaf-disease-tfrecords-center-{HEIGHT_DT}x{WIDTH_DT}') # Center croped and resized (50 TFRecord)
# GCS_PATH_EXT = KaggleDatasets().get_gcs_path(f'cassava-leaf-disease-tfrecords-external-{HEIGHT_DT}x{WIDTH_DT}') # Center croped and resized (50 TFRecord) (External)
# GCS_PATH_CLASSES = KaggleDatasets().get_gcs_path(f'cassava-leaf-disease-tfrecords-classes-{HEIGHT_DT}x{WIDTH_DT}') # Center croped and resized (50 TFRecord) by classes
# GCS_PATH_EXT_CLASSES = KaggleDatasets().get_gcs_path(f'cassava-leaf-disease-tfrecords-classes-ext-{HEIGHT_DT}x{WIDTH_DT}') # Center croped and resized (50 TFRecord) (External) by classes


FILENAMES_COMP = tf.io.gfile.glob(GCS_PATH + '/*.tfrec')
# FILENAMES_2019 = tf.io.gfile.glob(GCS_PATH_EXT + '/*.tfrec')

# FILENAMES_COMP_CBB = tf.io.gfile.glob(GCS_PATH_CLASSES + '/CBB*.tfrec')
# FILENAMES_COMP_CBSD = tf.io.gfile.glob(GCS_PATH_CLASSES + '/CBSD*.tfrec')
# FILENAMES_COMP_CGM = tf.io.gfile.glob(GCS_PATH_CLASSES + '/CGM*.tfrec')
# FILENAMES_COMP_CMD = tf.io.gfile.glob(GCS_PATH_CLASSES + '/CMD*.tfrec')
# FILENAMES_COMP_Healthy = tf.io.gfile.glob(GCS_PATH_CLASSES + '/Healthy*.tfrec')

# FILENAMES_2019_CBB = tf.io.gfile.glob(GCS_PATH_EXT_CLASSES + '/CBB*.tfrec')
# FILENAMES_2019_CBSD = tf.io.gfile.glob(GCS_PATH_EXT_CLASSES + '/CBSD*.tfrec')
# FILENAMES_2019_CGM = tf.io.gfile.glob(GCS_PATH_EXT_CLASSES + '/CGM*.tfrec')
# FILENAMES_2019_CMD = tf.io.gfile.glob(GCS_PATH_EXT_CLASSES + '/CMD*.tfrec')
# FILENAMES_2019_Healthy = tf.io.gfile.glob(GCS_PATH_EXT_CLASSES + '/Healthy*.tfrec')

TRAINING_FILENAMES = FILENAMES_COMP
NUM_TRAINING_IMAGES = count_data_items(TRAINING_FILENAMES)

print(f'GCS: train images: {NUM_TRAINING_IMAGES}')
display(train.head())
# Out:
# Train samples: 21397
# GCS: train images: 21395
#          image_id  label
# 0  1000015157.jpg      0
# 1  1000201771.jpg      3
# 2   100042118.jpg      1
# 3  1000723321.jpg      1
# 4  1000812911.jpg      3

# %% [markdown]
# # Augmentation

# %%
def data_augment(image, label):
#     p_rotation = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_spatial = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_rotate = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_pixel_1 = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_pixel_2 = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_pixel_3 = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
#     p_shear = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_crop = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_cutout = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    
#     # Shear
#     if p_shear > .2:
#         if p_shear > .6:
#             image = transform_shear(image, HEIGHT, shear=20.)
#         else:
#             image = transform_shear(image, HEIGHT, shear=-20.)
            
#     # Rotation
#     if p_rotation > .2:
#         if p_rotation > .6:
#             image = transform_rotation(image, HEIGHT, rotation=45.)
#         else:
#             image = transform_rotation(image, HEIGHT, rotation=-45.)
            
    # Flips
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    if p_spatial > .75:
        image = tf.image.transpose(image)
        
    # Rotates
    if p_rotate > .75:
        image = tf.image.rot90(image, k=3) # rotate 270º
    elif p_rotate > .5:
        image = tf.image.rot90(image, k=2) # rotate 180º
    elif p_rotate > .25:
        image = tf.image.rot90(image, k=1) # rotate 90º
        
    # Pixel-level transforms
    if p_pixel_1 >= .4:
        image = tf.image.random_saturation(image, lower=.7, upper=1.3)
    if p_pixel_2 >= .4:
        image = tf.image.random_contrast(image, lower=.8, upper=1.2)
    if p_pixel_3 >= .4:
        image = tf.image.random_brightness(image, max_delta=.1)
        
    # Crops
    if p_crop > .6:
        if p_crop > .9:
            image = tf.image.central_crop(image, central_fraction=.5)
        elif p_crop > .8:
            image = tf.image.central_crop(image, central_fraction=.6)
        elif p_crop > .7:
            image = tf.image.central_crop(image, central_fraction=.7)
        else:
            image = tf.image.central_crop(image, central_fraction=.8)
    elif p_crop > .3:
        crop_size = tf.random.uniform([], int(HEIGHT*.6), HEIGHT, dtype=tf.int32)
        image = tf.image.random_crop(image, size=[crop_size, crop_size, CHANNELS])
            
    image = tf.image.resize(image, size=[HEIGHT, WIDTH])

    if p_cutout > .5:
        image = data_augment_cutout(image)
        
    return image, label

# %% [markdown]
# ## Auxiliary functions

# %%
# CutOut
def data_augment_cutout(image, min_mask_size=(int(HEIGHT * .1), int(HEIGHT * .1)), 
                        max_mask_size=(int(HEIGHT * .125), int(HEIGHT * .125))):
    p_cutout = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    
    if p_cutout > .85: # 10~15 cut outs
        n_cutout = tf.random.uniform([], 10, 15, dtype=tf.int32)
        image = random_cutout(image, HEIGHT, WIDTH, 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=n_cutout)
    elif p_cutout > .6: # 5~10 cut outs
        n_cutout = tf.random.uniform([], 5, 10, dtype=tf.int32)
        image = random_cutout(image, HEIGHT, WIDTH, 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=n_cutout)
    elif p_cutout > .25: # 2~5 cut outs
        n_cutout = tf.random.uniform([], 2, 5, dtype=tf.int32)
        image = random_cutout(image, HEIGHT, WIDTH, 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=n_cutout)
    else: # 1 cut out
        image = random_cutout(image, HEIGHT, WIDTH, 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=1)

    return image

# %%
# Datasets utility functions
def random_crop(image, label):
    """
        Resize and reshape images to the expected size.
    """
    image = tf.image.random_crop(image, size=[HEIGHT, WIDTH, CHANNELS])
    return image, label

def prepare_image(image, label):
    """
        Resize and reshape images to the expected size.
    """
    image = tf.image.resize(image, [HEIGHT, WIDTH])
    image = tf.reshape(image, [HEIGHT, WIDTH, CHANNELS])
    return image, label

def center_crop_(image, label, height_rs, width_rs, height=HEIGHT_DT, width=WIDTH_DT, channels=3):
    image = tf.reshape(image, [height, width, channels]) # Original shape
    
    h, w = image.shape[0], image.shape[1]
    if h > w:
        image = tf.image.crop_to_bounding_box(image, (h - w) // 2, 0, w, w)
    else:
        image = tf.image.crop_to_bounding_box(image, 0, (w - h) // 2, h, h)
        
    image = tf.image.resize(image, [height_rs, width_rs]) # Expected shape
    return image, label


def read_tfrecord_(example, labeled=True, n_classes=5):
    """
        1. Parse data based on the 'TFREC_FORMAT' map.
        2. Decode image.
        3. If 'labeled' returns (image, label) if not (image, name).
    """
    if labeled:
        TFREC_FORMAT = {
            'image': tf.io.FixedLenFeature([], tf.string), 
            'target': tf.io.FixedLenFeature([], tf.int64), 
        }
    else:
        TFREC_FORMAT = {
            'image': tf.io.FixedLenFeature([], tf.string), 
            'image_name': tf.io.FixedLenFeature([], tf.string), 
        }
    example = tf.io.parse_single_example(example, TFREC_FORMAT)
    image = decode_image(example['image'])
    if labeled:
        label_or_name = tf.cast(example['target'], tf.int32)
#         # One-Hot Encoding needed to use "categorical_crossentropy" loss
#         label_or_name = tf.one_hot(tf.cast(label_or_name, tf.int32), n_classes)
    else:
        label_or_name = example['image_name']
    return image, label_or_name

def get_dataset(filenames, labeled=True, ordered=False, repeated=False, 
                cached=False, augment=False, batch_size=BATCH_SIZE):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    
    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False
        dataset = tf.data.Dataset.list_files(filenames)
        dataset = dataset.interleave(tf.data.TFRecordDataset, num_parallel_calls=AUTO)
    else:
        dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTO)
        
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTO)
        
    dataset = dataset.with_options(ignore_order)
    
    dataset = dataset.map(lambda x: read_tfrecord_(x, labeled=labeled), num_parallel_calls=AUTO)
    
    if augment:
        dataset = dataset.map(data_augment, num_parallel_calls=AUTO)
        
    dataset = dataset.map(scale_image, num_parallel_calls=AUTO)
    dataset = dataset.map(prepare_image, num_parallel_calls=AUTO)
    
    if labeled:
        dataset = dataset.map(conf_output, num_parallel_calls=AUTO)
    
    if not ordered:
        dataset = dataset.shuffle(2048)
    if repeated:
        dataset = dataset.repeat()
        
    dataset = dataset.batch(batch_size)
    
    if cached:
        dataset = dataset.cache()
    dataset = dataset.prefetch(AUTO)
    return dataset

def conf_output(image, label):
    """
        Configure the output of the dataset.
    """
    aux_label = [0.]
    aux_2_label = [0.]
    
    if label == 4: # Healthy
        aux_label = [1.]
    if label == 3: # CMD
        aux_2_label = [1.]
        
    label_one_hot = tf.one_hot(tf.cast(label, tf.int32), N_CLASSES)
        
    return (image, {'output_scl': label, 'output_healthy_scl': aux_label, 'output_cmd_scl': aux_2_label, 
                    'output': label_one_hot, 'output_healthy': aux_label, 'output_cmd': aux_2_label})

# %% [markdown]
# # Training data samples (with augmentation)

# %%
# train_dataset = get_dataset(FILENAMES_COMP, ordered=True, augment=True)
# train_iter = iter(train_dataset.unbatch().batch(20))

# display_batch_of_images(next(train_iter))
# display_batch_of_images(next(train_iter))

# %% [markdown]
# # Model

# %%
class UnitNormLayer(L.Layer):
    """
    Normalize vectors (euclidean norm) in batch to unit hypersphere.
    """
    def __init__(self, **kwargs):
        super(UnitNormLayer, self).__init__(**kwargs)

    def call(self, input_tensor):
        norm = tf.norm(input_tensor, axis=1)
        return input_tensor / tf.reshape(norm, [-1, 1])
    
def encoder_fn(input_shape):
    inputs = L.Input(shape=input_shape, name='input_image')
    base_model = efn.EfficientNetB3(input_tensor=inputs, 
                                    include_top=False, 
                                    weights='noisy-student', 
                                    pooling='avg')
    
    norm_embeddings = UnitNormLayer()(base_model.output)
    
    model = Model(inputs=inputs, outputs=norm_embeddings)
    return model

def model_fn(input_shape, N_CLASSES, encoder):
    inputs = L.Input(shape=input_shape, name='input_image')
    
    # Encoder
    unfreeze_model(encoder) # unfreeze all layers except "batch normalization"
    features = encoder(inputs)
    
    # Projection head
    outputs = L.Dense(128, activation='relu', name='projection_head')(features)
    output_scl = UnitNormLayer(name='output_scl')(outputs)

    output_healthy = L.Dense(128, activation='relu', name='projection_head_aux1')(features)
    output_healthy_scl = UnitNormLayer(name='output_healthy_scl')(output_healthy)

    output_cmd = L.Dense(128, activation='relu', name='projection_head_aux2')(features)
    output_cmd_scl = UnitNormLayer(name='output_cmd_scl')(output_cmd)
    
    # Classification head
    features = L.Dropout(.5)(features)
    features = L.Dense(512, activation='relu')(features)
    features = L.Dropout(.5)(features)
    
    output = L.Dense(N_CLASSES, activation='softmax', name='output')(features)
    output_healthy = L.Dense(1, activation='sigmoid', name='output_healthy')(features)
    output_cmd = L.Dense(1, activation='sigmoid', name='output_cmd')(features)
    
    model = Model(inputs=inputs, outputs=[output, output_healthy, output_cmd, 
                                          output_scl, output_healthy_scl, output_cmd_scl])
    return model

# %%
temperature = 0.1

class SupervisedContrastiveLoss(losses.Loss):
    def __init__(self, temperature=0.1, name=None):
        super(SupervisedContrastiveLoss, self).__init__(name=name)
        self.temperature = temperature

    def __call__(self, labels, feature_vectors, sample_weight=None):
        # Normalize feature vectors
        feature_vectors_normalized = tf.math.l2_normalize(feature_vectors, axis=1)
        # Compute logits
        logits = tf.divide(
            tf.matmul(
                feature_vectors_normalized, tf.transpose(feature_vectors_normalized)
            ),
            temperature,
        )
        return tfa.losses.npairs_loss(tf.squeeze(labels), logits)

# %% [markdown]
# ### Learning rate schedule

# %%
lr_start = 1e-8
lr_min = 1e-6
lr_max = LEARNING_RATE
num_cycles = 3
warmup_epochs = 3
hold_max_epochs = 0
total_epochs = EPOCHS
step_size = (NUM_TRAINING_IMAGES//BATCH_SIZE)
hold_max_steps = hold_max_epochs * step_size
total_steps = total_epochs * step_size
warmup_steps = warmup_epochs * step_size


def lrfn(total_steps, warmup_steps=0, lr_start=1e-4, lr_max=1e-3, lr_min=1e-4, num_cycles=1.):
    @tf.function
    def cosine_with_hard_restarts_schedule_with_warmup_(step):
        """ Create a schedule with a learning rate that decreases following the
        values of the cosine function with several hard restarts, after a warmup
        period during which it increases linearly between 0 and 1.
        """

        if step < warmup_steps:
            lr = (lr_max - lr_start) / warmup_steps * step + lr_start
        else:
            progress = (step - warmup_steps) / (total_steps - warmup_steps)
            lr = lr_max * (0.5 * (1.0 + tf.math.cos(np.pi * ((num_cycles * progress) % 1.0))))
            if lr_min is not None:
                lr = tf.math.maximum(lr_min, float(lr))
        return lr
    return cosine_with_hard_restarts_schedule_with_warmup_

lrfn_fn = lrfn(total_steps, warmup_steps, lr_start, lr_max, lr_min, num_cycles)
rng = [i for i in range(total_steps)]
y = [lrfn_fn(tf.cast(x, tf.float32)) for x in rng]

sns.set(style='whitegrid')
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)

print(f'{total_steps} total steps and {step_size} steps per epoch')
print(f'Learning rate schedule: {y[0]:.3g} to {max(y):.3g} to {y[-1]:.3g}')
# Out:
# 11022 total steps and 334 steps per epoch
# Learning rate schedule: 1e-08 to 8e-05 to 1e-06

# %% [markdown]
# # Training

# %%
skf = KFold(n_splits=N_FOLDS, shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; oof_names = []; oof_folds = []; history_list = []; oof_embed = []

for fold,(idxT, idxV) in enumerate(skf.split(np.arange(15))):
    if fold >= FOLDS_USED:
        break
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    K.clear_session()
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {idxT} VALID: {idxV}')

    # Create train and validation sets
    TRAIN_FILENAMES = tf.io.gfile.glob([GCS_PATH + '/Id_train%.2i*.tfrec' % x for x in idxT])
#     FILENAMES_COMP_CBB = tf.io.gfile.glob([GCS_PATH_CLASSES + '/CBB%.2i*.tfrec' % x for x in idxT])
#     FILENAMES_COMP_CBSD = tf.io.gfile.glob([GCS_PATH_CLASSES + '/CBSD%.2i*.tfrec' % x for x in idxT])
#     FILENAMES_COMP_CGM = tf.io.gfile.glob([GCS_PATH_CLASSES + '/CGM%.2i*.tfrec' % x for x in idxT])
#     FILENAMES_COMP_Healthy = tf.io.gfile.glob([GCS_PATH_CLASSES + '/Healthy%.2i*.tfrec' % x for x in idxT])
    
    VALID_FILENAMES = tf.io.gfile.glob([GCS_PATH + '/Id_train%.2i*.tfrec' % x for x in idxV])
    np.random.shuffle(TRAIN_FILENAMES)
    
    ct_train = count_data_items(TRAIN_FILENAMES)
    ct_valid = count_data_items(VALID_FILENAMES)
    
    step_size = (ct_train // BATCH_SIZE)
    warmup_steps = (warmup_epochs * step_size)
    total_steps = (total_epochs * step_size)
    
    with strategy.scope():
        encoder = encoder_fn((None, None, CHANNELS))
        model = model_fn((None, None, CHANNELS), N_CLASSES, encoder)
        model.summary()

        lrfn_fn = lrfn(total_steps, warmup_steps, lr_start, lr_max, lr_min, num_cycles)
        optimizer = optimizers.Adam(learning_rate=lambda: lrfn_fn(tf.cast(optimizer.iterations, tf.float32)))
        model.compile(optimizer=optimizer, 
                      loss={'output': losses.CategoricalCrossentropy(label_smoothing=.3), 
                            'output_healthy': losses.BinaryCrossentropy(label_smoothing=.1), 
                            'output_cmd': losses.BinaryCrossentropy(label_smoothing=.1), 
                            'output_scl': SupervisedContrastiveLoss(temperature), 
                            'output_healthy_scl': SupervisedContrastiveLoss(temperature), 
                            'output_cmd_scl': SupervisedContrastiveLoss(temperature)}, 
                      loss_weights={'output': 2., 
                                    'output_healthy': .1, 
                                    'output_cmd': .1, 
                                    'output_scl': 1., 
                                    'output_healthy_scl': .1, 
                                    'output_cmd_scl': .1, }, 
                      metrics={'output': metrics.CategoricalAccuracy(), 
                               'output_healthy': metrics.BinaryAccuracy(), 
                               'output_cmd': metrics.BinaryAccuracy()})
        
    
    model_path = f'model_{fold}.h5'
    ckpoint = ModelCheckpoint(model_path, mode='max', verbose=0, 
                              save_best_only=True, save_weights_only=True, 
                              monitor='val_output_categorical_accuracy')
    es = EarlyStopping(patience=ES_PATIENCE, mode='max', 
                       restore_best_weights=True, verbose=1, 
                       monitor='val_output_categorical_accuracy')
    history = model.fit(x=get_dataset(TRAIN_FILENAMES, repeated=True, augment=True), 
                        validation_data=get_dataset(VALID_FILENAMES, ordered=True), 
                        steps_per_epoch=step_size, 
                        batch_size=BATCH_SIZE, 
                        epochs=EPOCHS,
                        callbacks=[ckpoint, es], 
                        verbose=2).history
    
    
    ### RESULTS
    print(f"#### FOLD {fold+1} OOF Accuracy = {np.max(history['val_output_categorical_accuracy']):.3f}")
    
    history_list.append(history)
    # Load best model weights
    model.load_weights(model_path)

    # OOF predictions
    ds_valid = get_dataset(VALID_FILENAMES, ordered=True)
    oof_folds.append(np.full((ct_valid), fold, dtype='int8'))
    oof_labels.append([target['output'].numpy() for img, target in iter(ds_valid.unbatch())])
    x_oof = ds_valid.map(lambda image, target: image)
    oof_pred.append(model.predict(x_oof)[0])
    # OOF names
    ds_valid_names = get_dataset(VALID_FILENAMES, labeled=False, ordered=True)
    oof_names.append(np.array([img_name.numpy().decode('utf-8') for img, img_name in iter(ds_valid_names.unbatch())]))
    oof_embed.append(encoder.predict(x_oof)) # OOF embeddings
# Out:
# FOLD: 1
# TRAIN: [ 0  2  3  4  5  7  9 10 11 12 13 14] VALID: [1 6 8]
# Downloading data from https://github.com/qubvel/efficientnet/releases/download/v0.0.1/efficientnet-b3_noisy-student_notop.h5
# 43933696/43933088 [==============================] - 1s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, None, None,  0
# __________________________________________________________________________________________________
# model (Functional)              (None, 1536)         10783528    input_image[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1536)         0           model[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          786944      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# projection_head (Dense)         (None, 128)          196736      model[0][0]
# __________________________________________________________________________________________________
# projection_head_aux1 (Dense)    (None, 128)          196736      model[0][0]
# __________________________________________________________________________________________________
# projection_head_aux2 (Dense)    (None, 128)          196736      model[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 5)            2565        dropout_1[0][0]
# __________________________________________________________________________________________________
# output_healthy (Dense)          (None, 1)            513         dropout_1[0][0]
# __________________________________________________________________________________________________
# output_cmd (Dense)              (None, 1)            513         dropout_1[0][0]
# __________________________________________________________________________________________________
# output_scl (UnitNormLayer)      (None, 128)          0           projection_head[0][0]
# __________________________________________________________________________________________________
# output_healthy_scl (UnitNormLay (None, 128)          0           projection_head_aux1[0][0]
# __________________________________________________________________________________________________
# output_cmd_scl (UnitNormLayer)  (None, 128)          0           projection_head_aux2[0][0]
# ==================================================================================================
# Total params: 12,164,271
# Trainable params: 11,989,679
# Non-trainable params: 174,592
# __________________________________________________________________________________________________
# Epoch 1/33
# 267/267 - 153s - loss: 5.4271 - output_loss: 1.4971 - output_healthy_loss: 0.6552 - output_cmd_loss: 0.6879 - output_scl_loss: 1.8496 - output_healthy_scl_loss: 2.2753 - output_cmd_scl_loss: 2.2148 - output_categorical_accuracy: 0.5194 - output_healthy_binary_accuracy: 0.8085 - output_cmd_binary_accuracy: 0.5544 - val_loss: nan - val_output_loss: 1.3059 - val_output_healthy_loss: 0.5919 - val_output_cmd_loss: 0.6682 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.6156 - val_output_healthy_binary_accuracy: 0.8796 - val_output_cmd_binary_accuracy: 0.6167
# Epoch 2/33
# 267/267 - 62s - loss: 4.5135 - output_loss: 1.2168 - output_healthy_loss: 0.5212 - output_cmd_loss: 0.5733 - output_scl_loss: 1.5847 - output_healthy_scl_loss: 2.0347 - output_cmd_scl_loss: 1.8223 - output_categorical_accuracy: 0.7063 - output_healthy_binary_accuracy: 0.8754 - output_cmd_binary_accuracy: 0.8272 - val_loss: nan - val_output_loss: 1.1502 - val_output_healthy_loss: 0.4394 - val_output_cmd_loss: 0.4887 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.7864 - val_output_healthy_binary_accuracy: 0.8799 - val_output_cmd_binary_accuracy: 0.8523
# Epoch 3/33
# 267/267 - 59s - loss: 4.2127 - output_loss: 1.1165 - output_healthy_loss: 0.4047 - output_cmd_loss: 0.4276 - output_scl_loss: 1.5221 - output_healthy_scl_loss: 1.9994 - output_cmd_scl_loss: 1.7452 - output_categorical_accuracy: 0.8150 - output_healthy_binary_accuracy: 0.8793 - output_cmd_binary_accuracy: 0.9030 - val_loss: nan - val_output_loss: 1.0535 - val_output_healthy_loss: 0.3712 - val_output_cmd_loss: 0.3647 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8656 - val_output_healthy_binary_accuracy: 0.8799 - val_output_cmd_binary_accuracy: 0.9334
# Epoch 4/33
# 267/267 - 57s - loss: 4.0622 - output_loss: 1.0693 - output_healthy_loss: 0.3644 - output_cmd_loss: 0.3550 - output_scl_loss: 1.4814 - output_healthy_scl_loss: 1.9836 - output_cmd_scl_loss: 1.7176 - output_categorical_accuracy: 0.8541 - output_healthy_binary_accuracy: 0.8848 - output_cmd_binary_accuracy: 0.9328 - val_loss: nan - val_output_loss: 1.0302 - val_output_healthy_loss: 0.3427 - val_output_cmd_loss: 0.3197 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8768 - val_output_healthy_binary_accuracy: 0.9149 - val_output_cmd_binary_accuracy: 0.9444
# Epoch 5/33
# 267/267 - 57s - loss: 3.9960 - output_loss: 1.0502 - output_healthy_loss: 0.3414 - output_cmd_loss: 0.3203 - output_scl_loss: 1.4625 - output_healthy_scl_loss: 1.9719 - output_cmd_scl_loss: 1.6982 - output_categorical_accuracy: 0.8717 - output_healthy_binary_accuracy: 0.9111 - output_cmd_binary_accuracy: 0.9421 - val_loss: nan - val_output_loss: 1.0364 - val_output_healthy_loss: 0.3293 - val_output_cmd_loss: 0.3272 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8761 - val_output_healthy_binary_accuracy: 0.9266 - val_output_cmd_binary_accuracy: 0.9339
# Epoch 6/33
# 267/267 - 57s - loss: 3.9536 - output_loss: 1.0395 - output_healthy_loss: 0.3265 - output_cmd_loss: 0.3033 - output_scl_loss: 1.4462 - output_healthy_scl_loss: 1.9663 - output_cmd_scl_loss: 1.6880 - output_categorical_accuracy: 0.8787 - output_healthy_binary_accuracy: 0.9283 - output_cmd_binary_accuracy: 0.9484 - val_loss: nan - val_output_loss: 1.0269 - val_output_healthy_loss: 0.3167 - val_output_cmd_loss: 0.2894 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8836 - val_output_healthy_binary_accuracy: 0.9353 - val_output_cmd_binary_accuracy: 0.9528
# Epoch 7/33
# 267/267 - 57s - loss: 3.9311 - output_loss: 1.0346 - output_healthy_loss: 0.3198 - output_cmd_loss: 0.2972 - output_scl_loss: 1.4354 - output_healthy_scl_loss: 1.9624 - output_cmd_scl_loss: 1.6857 - output_categorical_accuracy: 0.8836 - output_healthy_binary_accuracy: 0.9305 - output_cmd_binary_accuracy: 0.9514 - val_loss: nan - val_output_loss: 1.0266 - val_output_healthy_loss: 0.3108 - val_output_cmd_loss: 0.2951 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8832 - val_output_healthy_binary_accuracy: 0.9353 - val_output_cmd_binary_accuracy: 0.9470
# Epoch 8/33
# 267/267 - 58s - loss: 3.9051 - output_loss: 1.0273 - output_healthy_loss: 0.3122 - output_cmd_loss: 0.2871 - output_scl_loss: 1.4273 - output_healthy_scl_loss: 1.9613 - output_cmd_scl_loss: 1.6716 - output_categorical_accuracy: 0.8883 - output_healthy_binary_accuracy: 0.9347 - output_cmd_binary_accuracy: 0.9543 - val_loss: nan - val_output_loss: 1.0244 - val_output_healthy_loss: 0.3069 - val_output_cmd_loss: 0.2880 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8850 - val_output_healthy_binary_accuracy: 0.9362 - val_output_cmd_binary_accuracy: 0.9507
# Epoch 9/33
# 267/267 - 59s - loss: 3.8930 - output_loss: 1.0237 - output_healthy_loss: 0.3089 - output_cmd_loss: 0.2853 - output_scl_loss: 1.4234 - output_healthy_scl_loss: 1.9573 - output_cmd_scl_loss: 1.6720 - output_categorical_accuracy: 0.8919 - output_healthy_binary_accuracy: 0.9386 - output_cmd_binary_accuracy: 0.9559 - val_loss: nan - val_output_loss: 1.0188 - val_output_healthy_loss: 0.3022 - val_output_cmd_loss: 0.2837 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8881 - val_output_healthy_binary_accuracy: 0.9364 - val_output_cmd_binary_accuracy: 0.9530
# Epoch 10/33
# 267/267 - 58s - loss: 3.8634 - output_loss: 1.0162 - output_healthy_loss: 0.3034 - output_cmd_loss: 0.2814 - output_scl_loss: 1.4116 - output_healthy_scl_loss: 1.9511 - output_cmd_scl_loss: 1.6579 - output_categorical_accuracy: 0.8982 - output_healthy_binary_accuracy: 0.9421 - output_cmd_binary_accuracy: 0.9573 - val_loss: nan - val_output_loss: 1.0190 - val_output_healthy_loss: 0.3012 - val_output_cmd_loss: 0.2870 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8864 - val_output_healthy_binary_accuracy: 0.9374 - val_output_cmd_binary_accuracy: 0.9512
# Epoch 11/33
# 267/267 - 58s - loss: 3.8519 - output_loss: 1.0118 - output_healthy_loss: 0.3002 - output_cmd_loss: 0.2772 - output_scl_loss: 1.4096 - output_healthy_scl_loss: 1.9510 - output_cmd_scl_loss: 1.6581 - output_categorical_accuracy: 0.9033 - output_healthy_binary_accuracy: 0.9419 - output_cmd_binary_accuracy: 0.9601 - val_loss: nan - val_output_loss: 1.0173 - val_output_healthy_loss: 0.2996 - val_output_cmd_loss: 0.2845 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8874 - val_output_healthy_binary_accuracy: 0.9388 - val_output_cmd_binary_accuracy: 0.9533
# Epoch 12/33
# 267/267 - 59s - loss: 3.8279 - output_loss: 1.0089 - output_healthy_loss: 0.2996 - output_cmd_loss: 0.2759 - output_scl_loss: 1.3930 - output_healthy_scl_loss: 1.9441 - output_cmd_scl_loss: 1.6510 - output_categorical_accuracy: 0.9055 - output_healthy_binary_accuracy: 0.9438 - output_cmd_binary_accuracy: 0.9618 - val_loss: nan - val_output_loss: 1.0174 - val_output_healthy_loss: 0.2998 - val_output_cmd_loss: 0.2845 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8876 - val_output_healthy_binary_accuracy: 0.9374 - val_output_cmd_binary_accuracy: 0.9530
# Epoch 13/33
# 267/267 - 58s - loss: 3.8280 - output_loss: 1.0076 - output_healthy_loss: 0.2975 - output_cmd_loss: 0.2743 - output_scl_loss: 1.3966 - output_healthy_scl_loss: 1.9440 - output_cmd_scl_loss: 1.6460 - output_categorical_accuracy: 0.9062 - output_healthy_binary_accuracy: 0.9449 - output_cmd_binary_accuracy: 0.9613 - val_loss: nan - val_output_loss: 1.0174 - val_output_healthy_loss: 0.2998 - val_output_cmd_loss: 0.2838 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8878 - val_output_healthy_binary_accuracy: 0.9383 - val_output_cmd_binary_accuracy: 0.9521
# Epoch 14/33
# 267/267 - 60s - loss: 3.9067 - output_loss: 1.0270 - output_healthy_loss: 0.3025 - output_cmd_loss: 0.2885 - output_scl_loss: 1.4303 - output_healthy_scl_loss: 1.9587 - output_cmd_scl_loss: 1.6731 - output_categorical_accuracy: 0.8910 - output_healthy_binary_accuracy: 0.9392 - output_cmd_binary_accuracy: 0.9527 - val_loss: nan - val_output_loss: 1.0211 - val_output_healthy_loss: 0.3007 - val_output_cmd_loss: 0.2911 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8860 - val_output_healthy_binary_accuracy: 0.9369 - val_output_cmd_binary_accuracy: 0.9491
# Epoch 15/33
# 267/267 - 59s - loss: 3.8864 - output_loss: 1.0221 - output_healthy_loss: 0.2988 - output_cmd_loss: 0.2845 - output_scl_loss: 1.4214 - output_healthy_scl_loss: 1.9542 - output_cmd_scl_loss: 1.6697 - output_categorical_accuracy: 0.8912 - output_healthy_binary_accuracy: 0.9402 - output_cmd_binary_accuracy: 0.9532 - val_loss: nan - val_output_loss: 1.0200 - val_output_healthy_loss: 0.2952 - val_output_cmd_loss: 0.2866 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8867 - val_output_healthy_binary_accuracy: 0.9409 - val_output_cmd_binary_accuracy: 0.9505
# Epoch 16/33
# 267/267 - 59s - loss: 3.8760 - output_loss: 1.0185 - output_healthy_loss: 0.2966 - output_cmd_loss: 0.2798 - output_scl_loss: 1.4196 - output_healthy_scl_loss: 1.9531 - output_cmd_scl_loss: 1.6642 - output_categorical_accuracy: 0.8971 - output_healthy_binary_accuracy: 0.9424 - output_cmd_binary_accuracy: 0.9587 - val_loss: nan - val_output_loss: 1.0263 - val_output_healthy_loss: 0.2967 - val_output_cmd_loss: 0.2948 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8853 - val_output_healthy_binary_accuracy: 0.9406 - val_output_cmd_binary_accuracy: 0.9453
# Epoch 17/33
# 267/267 - 60s - loss: 3.8529 - output_loss: 1.0116 - output_healthy_loss: 0.2912 - output_cmd_loss: 0.2768 - output_scl_loss: 1.4119 - output_healthy_scl_loss: 1.9463 - output_cmd_scl_loss: 1.6643 - output_categorical_accuracy: 0.9015 - output_healthy_binary_accuracy: 0.9452 - output_cmd_binary_accuracy: 0.9591 - val_loss: nan - val_output_loss: 1.0178 - val_output_healthy_loss: 0.2944 - val_output_cmd_loss: 0.2847 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8881 - val_output_healthy_binary_accuracy: 0.9383 - val_output_cmd_binary_accuracy: 0.9521
# Epoch 18/33
# 267/267 - 59s - loss: 3.8376 - output_loss: 1.0086 - output_healthy_loss: 0.2903 - output_cmd_loss: 0.2765 - output_scl_loss: 1.4035 - output_healthy_scl_loss: 1.9463 - output_cmd_scl_loss: 1.6555 - output_categorical_accuracy: 0.9038 - output_healthy_binary_accuracy: 0.9467 - output_cmd_binary_accuracy: 0.9594 - val_loss: nan - val_output_loss: 1.0172 - val_output_healthy_loss: 0.2926 - val_output_cmd_loss: 0.2848 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8909 - val_output_healthy_binary_accuracy: 0.9390 - val_output_cmd_binary_accuracy: 0.9516
# Epoch 19/33
# 267/267 - 59s - loss: 3.8024 - output_loss: 1.0012 - output_healthy_loss: 0.2840 - output_cmd_loss: 0.2692 - output_scl_loss: 1.3869 - output_healthy_scl_loss: 1.9351 - output_cmd_scl_loss: 1.6419 - output_categorical_accuracy: 0.9119 - output_healthy_binary_accuracy: 0.9501 - output_cmd_binary_accuracy: 0.9636 - val_loss: nan - val_output_loss: 1.0153 - val_output_healthy_loss: 0.2920 - val_output_cmd_loss: 0.2829 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8944 - val_output_healthy_binary_accuracy: 0.9399 - val_output_cmd_binary_accuracy: 0.9537
# Epoch 20/33
# 267/267 - 57s - loss: 3.7856 - output_loss: 0.9974 - output_healthy_loss: 0.2826 - output_cmd_loss: 0.2661 - output_scl_loss: 1.3790 - output_healthy_scl_loss: 1.9355 - output_cmd_scl_loss: 1.6339 - output_categorical_accuracy: 0.9125 - output_healthy_binary_accuracy: 0.9510 - output_cmd_binary_accuracy: 0.9663 - val_loss: nan - val_output_loss: 1.0178 - val_output_healthy_loss: 0.2932 - val_output_cmd_loss: 0.2839 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8920 - val_output_healthy_binary_accuracy: 0.9395 - val_output_cmd_binary_accuracy: 0.9544
# Epoch 21/33
# 267/267 - 60s - loss: 3.7815 - output_loss: 0.9935 - output_healthy_loss: 0.2801 - output_cmd_loss: 0.2646 - output_scl_loss: 1.3830 - output_healthy_scl_loss: 1.9333 - output_cmd_scl_loss: 1.6377 - output_categorical_accuracy: 0.9180 - output_healthy_binary_accuracy: 0.9529 - output_cmd_binary_accuracy: 0.9661 - val_loss: nan - val_output_loss: 1.0163 - val_output_healthy_loss: 0.2922 - val_output_cmd_loss: 0.2837 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8932 - val_output_healthy_binary_accuracy: 0.9399 - val_output_cmd_binary_accuracy: 0.9530
# Epoch 22/33
# 267/267 - 59s - loss: 3.7634 - output_loss: 0.9906 - output_healthy_loss: 0.2780 - output_cmd_loss: 0.2606 - output_scl_loss: 1.3723 - output_healthy_scl_loss: 1.9328 - output_cmd_scl_loss: 1.6278 - output_categorical_accuracy: 0.9200 - output_healthy_binary_accuracy: 0.9550 - output_cmd_binary_accuracy: 0.9694 - val_loss: nan - val_output_loss: 1.0169 - val_output_healthy_loss: 0.2929 - val_output_cmd_loss: 0.2828 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8923 - val_output_healthy_binary_accuracy: 0.9402 - val_output_cmd_binary_accuracy: 0.9540
# Epoch 23/33
# 267/267 - 59s - loss: 3.7519 - output_loss: 0.9876 - output_healthy_loss: 0.2779 - output_cmd_loss: 0.2613 - output_scl_loss: 1.3680 - output_healthy_scl_loss: 1.9224 - output_cmd_scl_loss: 1.6268 - output_categorical_accuracy: 0.9221 - output_healthy_binary_accuracy: 0.9542 - output_cmd_binary_accuracy: 0.9680 - val_loss: nan - val_output_loss: 1.0164 - val_output_healthy_loss: 0.2926 - val_output_cmd_loss: 0.2829 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8934 - val_output_healthy_binary_accuracy: 0.9397 - val_output_cmd_binary_accuracy: 0.9540
# Epoch 24/33
# 267/267 - 59s - loss: 3.8477 - output_loss: 1.0116 - output_healthy_loss: 0.2875 - output_cmd_loss: 0.2769 - output_scl_loss: 1.4076 - output_healthy_scl_loss: 1.9439 - output_cmd_scl_loss: 1.6598 - output_categorical_accuracy: 0.9019 - output_healthy_binary_accuracy: 0.9472 - output_cmd_binary_accuracy: 0.9596 - val_loss: nan - val_output_loss: 1.0281 - val_output_healthy_loss: 0.3020 - val_output_cmd_loss: 0.2877 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8829 - val_output_healthy_binary_accuracy: 0.9318 - val_output_cmd_binary_accuracy: 0.9526
# Epoch 25/33
# 267/267 - 59s - loss: 3.8215 - output_loss: 1.0042 - output_healthy_loss: 0.2847 - output_cmd_loss: 0.2720 - output_scl_loss: 1.3990 - output_healthy_scl_loss: 1.9395 - output_cmd_scl_loss: 1.6455 - output_categorical_accuracy: 0.9088 - output_healthy_binary_accuracy: 0.9497 - output_cmd_binary_accuracy: 0.9617 - val_loss: nan - val_output_loss: 1.0200 - val_output_healthy_loss: 0.2997 - val_output_cmd_loss: 0.2835 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8923 - val_output_healthy_binary_accuracy: 0.9336 - val_output_cmd_binary_accuracy: 0.9540
# Epoch 26/33
# 267/267 - 59s - loss: 3.8118 - output_loss: 1.0020 - output_healthy_loss: 0.2839 - output_cmd_loss: 0.2723 - output_scl_loss: 1.3934 - output_healthy_scl_loss: 1.9384 - output_cmd_scl_loss: 1.6501 - output_categorical_accuracy: 0.9110 - output_healthy_binary_accuracy: 0.9514 - output_cmd_binary_accuracy: 0.9618 - val_loss: nan - val_output_loss: 1.0185 - val_output_healthy_loss: 0.2951 - val_output_cmd_loss: 0.2846 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8857 - val_output_healthy_binary_accuracy: 0.9399 - val_output_cmd_binary_accuracy: 0.9523
# Epoch 27/33
# 267/267 - 58s - loss: 3.7811 - output_loss: 0.9961 - output_healthy_loss: 0.2796 - output_cmd_loss: 0.2664 - output_scl_loss: 1.3780 - output_healthy_scl_loss: 1.9296 - output_cmd_scl_loss: 1.6338 - output_categorical_accuracy: 0.9154 - output_healthy_binary_accuracy: 0.9528 - output_cmd_binary_accuracy: 0.9650 - val_loss: nan - val_output_loss: 1.0211 - val_output_healthy_loss: 0.2940 - val_output_cmd_loss: 0.2863 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8902 - val_output_healthy_binary_accuracy: 0.9395 - val_output_cmd_binary_accuracy: 0.9533
# Epoch 28/33
# 267/267 - 59s - loss: 3.7759 - output_loss: 0.9935 - output_healthy_loss: 0.2761 - output_cmd_loss: 0.2663 - output_scl_loss: 1.3780 - output_healthy_scl_loss: 1.9268 - output_cmd_scl_loss: 1.6384 - output_categorical_accuracy: 0.9171 - output_healthy_binary_accuracy: 0.9552 - output_cmd_binary_accuracy: 0.9651 - val_loss: nan - val_output_loss: 1.0196 - val_output_healthy_loss: 0.2953 - val_output_cmd_loss: 0.2844 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8927 - val_output_healthy_binary_accuracy: 0.9411 - val_output_cmd_binary_accuracy: 0.9547
# Epoch 29/33
# 267/267 - 60s - loss: 3.7479 - output_loss: 0.9847 - output_healthy_loss: 0.2709 - output_cmd_loss: 0.2612 - output_scl_loss: 1.3706 - output_healthy_scl_loss: 1.9223 - output_cmd_scl_loss: 1.6254 - output_categorical_accuracy: 0.9246 - output_healthy_binary_accuracy: 0.9585 - output_cmd_binary_accuracy: 0.9680 - val_loss: nan - val_output_loss: 1.0203 - val_output_healthy_loss: 0.2958 - val_output_cmd_loss: 0.2828 - val_output_scl_loss: nan - val_output_healthy_scl_loss: nan - val_output_cmd_scl_loss: nan - val_output_categorical_accuracy: 0.8904 - val_output_healthy_binary_accuracy: 0.9395 - val_output_cmd_binary_accuracy: 0.9547
# Restoring model weights from the end of the best epoch.
# Epoch 00029: early stopping
# #### FOLD 1 OOF Accuracy = 0.894

# %% [markdown]
# ## Model loss graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history, acc_name='output_categorical_accuracy')
# Out:
# FOLD: 1

# %% [markdown]
# # Model evaluation

# %%
y_true = np.concatenate(oof_labels)
y_true = np.argmax(y_true, axis=-1)
y_prob = np.concatenate(oof_pred)
y_pred = np.argmax(y_prob, axis=-1)
folds = np.concatenate(oof_folds)
names = np.concatenate(oof_names)

acc = accuracy_score(y_true, y_pred)
print(f'Overall OOF Accuracy = {acc:.3f}')

df_oof = pd.DataFrame({'image_id':names, 'fold':fold, 
                       'target':y_true, 'pred':y_pred})

df_oof = df_oof.assign(probs=[prob for prob in y_prob])
df_oof.to_csv('oof.csv', index=False)
display(df_oof.head())

print(classification_report(y_true, y_pred, target_names=CLASSES))
# Out:
# Overall OOF Accuracy = 0.895
#          image_id  fold  target  pred  \
# 0  1000201771.jpg     0       3     3
# 1  1000837476.jpg     0       3     3
# 2  1001723730.jpg     0       4     0
# 3  1001749118.jpg     0       3     3
# 4  1008284502.jpg     0       3     3
#
#                                                probs
# 0  [0.058106404, 0.05842433, 0.06101574, 0.764717...
# 1  [0.061909925, 0.060421336, 0.059592333, 0.7505...
# 2  [0.6878818, 0.091214456, 0.063655786, 0.063848...
# 3  [0.061285406, 0.05960717, 0.059090313, 0.75747...
# 4  [0.05889387, 0.05845862, 0.056953784, 0.765291...
#                               precision    recall  f1-score   support
#
#     Cassava Bacterial Blight       0.67      0.71      0.68       217
# Cassava Brown Streak Disease       0.86      0.82      0.84       437
#         Cassava Green Mottle       0.83      0.82      0.82       478
#       Cassava Mosaic Disease       0.95      0.97      0.96      2633
#                      Healthy       0.77      0.73      0.75       514
#
#                     accuracy                           0.89      4279
#                    macro avg       0.82      0.81      0.81      4279
#                 weighted avg       0.89      0.89      0.89      4279

# %% [markdown]
# # Confusion matrix

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 12))
cfn_matrix = confusion_matrix(y_true, y_pred, labels=range(len(CLASSES)))
cfn_matrix = (cfn_matrix.T / cfn_matrix.sum(axis=1)).T
df_cm = pd.DataFrame(cfn_matrix, index=CLASSES, columns=CLASSES)
ax = sns.heatmap(df_cm, cmap='Blues', annot=True, fmt='.2f', linewidths=.5).set_title('Train', fontsize=30)
plt.show()

# %% [markdown]
# # Visualize embeddings outputs

# %%
y_embeddings = np.concatenate(oof_embed)

visualize_embeddings(y_embeddings, y_true)

# %% [markdown]
# # Visualize predictions

# %%
# train_dataset = get_dataset(TRAINING_FILENAMES, ordered=True)
# x_samp, y_samp = dataset_to_numpy_util(train_dataset, 18)
# y_samp = np.argmax(y_samp, axis=-1)

# x_samp_1, y_samp_1 = x_samp[:9,:,:,:], y_samp[:9]
# samp_preds_1 = model.predict(x_samp_1, batch_size=9)
# display_9_images_with_predictions(x_samp_1, samp_preds_1, y_samp_1)

# x_samp_2, y_samp_2 = x_samp[9:,:,:,:], y_samp[9:]
# samp_preds_2 = model.predict(x_samp_2, batch_size=9)
# display_9_images_with_predictions(x_samp_2, samp_preds_2, y_samp_2)
