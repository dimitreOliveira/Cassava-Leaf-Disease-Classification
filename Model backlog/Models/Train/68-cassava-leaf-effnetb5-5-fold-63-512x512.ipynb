# %% [markdown]
# ## Dependencies

# %%
# !pip install --quiet efficientnet
# Out:
# WARNING: You are using pip version 20.1.1; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
import warnings, time
from kaggle_datasets import KaggleDatasets
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras import optimizers, Sequential, losses, metrics, Model
from tensorflow.keras.callbacks import EarlyStopping
import efficientnet.tfkeras as efn
from cassava_scripts import *
from scripts_step_lr_schedulers import *


seed = 0
seed_everything(seed)
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Hardware configuration

# %%
# TPU or GPU detection
# Detect hardware, return appropriate distribution strategy
strategy, tpu = set_up_strategy()

AUTO = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %% [markdown]
# # Model parameters

# %%
BATCH_SIZE = 8 * REPLICAS
LEARNING_RATE = 1e-5 * REPLICAS
EPOCHS = 33
HEIGHT = 512
WIDTH = 512
HEIGHT_DT = 512
WIDTH_DT = 512
CHANNELS = 3
N_CLASSES = 5
N_FOLDS = 5
FOLDS_USED = 5
ES_PATIENCE = 10

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/cassava-leaf-disease-classification/'
train = pd.read_csv(f'{database_base_path}train.csv')
print(f'Train samples: {len(train)}')

GCS_PATH = KaggleDatasets().get_gcs_path(f'cassava-leaf-disease-tfrecords-center-{HEIGHT_DT}x{WIDTH_DT}') # Center croped and resized (50 TFRecord)
GCS_PATH_EXT = KaggleDatasets().get_gcs_path(f'cassava-leaf-disease-tfrecords-external-{HEIGHT_DT}x{WIDTH_DT}') # Center croped and resized (50 TFRecord) (External)
GCS_PATH_CLASSES = KaggleDatasets().get_gcs_path(f'cassava-leaf-disease-tfrecords-classes-{HEIGHT_DT}x{WIDTH_DT}') # Center croped and resized (50 TFRecord) by classes
GCS_PATH_EXT_CLASSES = KaggleDatasets().get_gcs_path(f'cassava-leaf-disease-tfrecords-classes-ext-{HEIGHT_DT}x{WIDTH_DT}') # Center croped and resized (50 TFRecord) (External) by classes


FILENAMES_COMP = tf.io.gfile.glob(GCS_PATH + '/*.tfrec')
FILENAMES_2019 = tf.io.gfile.glob(GCS_PATH_EXT + '/*.tfrec')

# FILENAMES_COMP_CBB = tf.io.gfile.glob(GCS_PATH_CLASSES + '/CBB*.tfrec')
# FILENAMES_COMP_CBSD = tf.io.gfile.glob(GCS_PATH_CLASSES + '/CBSD*.tfrec')
# FILENAMES_COMP_CGM = tf.io.gfile.glob(GCS_PATH_CLASSES + '/CGM*.tfrec')
# FILENAMES_COMP_CMD = tf.io.gfile.glob(GCS_PATH_CLASSES + '/CMD*.tfrec')
# FILENAMES_COMP_Healthy = tf.io.gfile.glob(GCS_PATH_CLASSES + '/Healthy*.tfrec')

# FILENAMES_2019_CBB = tf.io.gfile.glob(GCS_PATH_EXT_CLASSES + '/CBB*.tfrec')
# FILENAMES_2019_CBSD = tf.io.gfile.glob(GCS_PATH_EXT_CLASSES + '/CBSD*.tfrec')
# FILENAMES_2019_CGM = tf.io.gfile.glob(GCS_PATH_EXT_CLASSES + '/CGM*.tfrec')
# FILENAMES_2019_CMD = tf.io.gfile.glob(GCS_PATH_EXT_CLASSES + '/CMD*.tfrec')
# FILENAMES_2019_Healthy = tf.io.gfile.glob(GCS_PATH_EXT_CLASSES + '/Healthy*.tfrec')


TRAINING_FILENAMES = (FILENAMES_COMP + FILENAMES_2019)

NUM_TRAINING_IMAGES = count_data_items(TRAINING_FILENAMES)

print(f'GCS: train images: {NUM_TRAINING_IMAGES}')
display(train.head())
# Out:
# Train samples: 21397
# GCS: train images: 26335
#          image_id  label
# 0  1000015157.jpg      0
# 1  1000201771.jpg      3
# 2   100042118.jpg      1
# 3  1000723321.jpg      1
# 4  1000812911.jpg      3

# %% [markdown]
# # Augmentation

# %%
def data_augment(image, label):
#     p_rotation = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_spatial = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_rotate = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_pixel_1 = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_pixel_2 = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_pixel_3 = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
#     p_shear = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_crop = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_cutout = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    
#     # Shear
#     if p_shear > .2:
#         if p_shear > .6:
#             image = transform_shear(image, HEIGHT, shear=20.)
#         else:
#             image = transform_shear(image, HEIGHT, shear=-20.)
            
#     # Rotation
#     if p_rotation > .2:
#         if p_rotation > .6:
#             image = transform_rotation(image, HEIGHT, rotation=45.)
#         else:
#             image = transform_rotation(image, HEIGHT, rotation=-45.)
            
    # Flips
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    if p_spatial > .75:
        image = tf.image.transpose(image)
        
    # Rotates
    if p_rotate > .75:
        image = tf.image.rot90(image, k=3) # rotate 270º
    elif p_rotate > .5:
        image = tf.image.rot90(image, k=2) # rotate 180º
    elif p_rotate > .25:
        image = tf.image.rot90(image, k=1) # rotate 90º
        
    # Pixel-level transforms
    if p_pixel_1 >= .4:
        image = tf.image.random_saturation(image, lower=.7, upper=1.3)
    if p_pixel_2 >= .4:
        image = tf.image.random_contrast(image, lower=.8, upper=1.2)
    if p_pixel_3 >= .4:
        image = tf.image.random_brightness(image, max_delta=.1)
        
    # Crops
    if p_crop > .6:
        if p_crop > .9:
            image = tf.image.central_crop(image, central_fraction=.5)
        elif p_crop > .8:
            image = tf.image.central_crop(image, central_fraction=.6)
        elif p_crop > .7:
            image = tf.image.central_crop(image, central_fraction=.7)
        else:
            image = tf.image.central_crop(image, central_fraction=.8)
    elif p_crop > .3:
        crop_size = tf.random.uniform([], int(HEIGHT*.6), HEIGHT, dtype=tf.int32)
        image = tf.image.random_crop(image, size=[crop_size, crop_size, CHANNELS])
            
    image = tf.image.resize(image, size=[HEIGHT, WIDTH])

    if p_cutout > .5:
        image = data_augment_cutout(image)
        
    return image, label

# %% [markdown]
# ## Auxiliary functions

# %%
# CutOut
def data_augment_cutout(image, min_mask_size=(int(HEIGHT * .1), int(HEIGHT * .1)), 
                        max_mask_size=(int(HEIGHT * .125), int(HEIGHT * .125))):
    p_cutout = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    
    if p_cutout > .85: # 10~15 cut outs
        n_cutout = tf.random.uniform([], 10, 15, dtype=tf.int32)
        image = random_cutout(image, HEIGHT, WIDTH, 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=n_cutout)
    elif p_cutout > .6: # 5~10 cut outs
        n_cutout = tf.random.uniform([], 5, 10, dtype=tf.int32)
        image = random_cutout(image, HEIGHT, WIDTH, 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=n_cutout)
    elif p_cutout > .25: # 2~5 cut outs
        n_cutout = tf.random.uniform([], 2, 5, dtype=tf.int32)
        image = random_cutout(image, HEIGHT, WIDTH, 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=n_cutout)
    else: # 1 cut out
        image = random_cutout(image, HEIGHT, WIDTH, 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=1)

    return image

# %%
# Datasets utility functions
def random_crop(image, label):
    """
        Resize and reshape images to the expected size.
    """
    image = tf.image.random_crop(image, size=[HEIGHT, WIDTH, CHANNELS])
    return image, label

def prepare_image(image, label):
    """
        Resize and reshape images to the expected size.
    """
    image = tf.image.resize(image, [HEIGHT, WIDTH])
    image = tf.reshape(image, [HEIGHT, WIDTH, CHANNELS])
    return image, label

def center_crop_(image, label, height_rs, width_rs, height=HEIGHT_DT, width=WIDTH_DT, channels=3):
    image = tf.reshape(image, [height, width, channels]) # Original shape
    
    h, w = image.shape[0], image.shape[1]
    if h > w:
        image = tf.image.crop_to_bounding_box(image, (h - w) // 2, 0, w, w)
    else:
        image = tf.image.crop_to_bounding_box(image, 0, (w - h) // 2, h, h)
        
    image = tf.image.resize(image, [height_rs, width_rs]) # Expected shape
    return image, label

def get_dataset(filenames, labeled=True, ordered=False, repeated=False, 
                cached=False, augment=False):
    """
        Return a Tensorflow dataset ready for training or inference.
    """
    
    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False
        dataset = tf.data.Dataset.list_files(filenames)
        dataset = dataset.interleave(tf.data.TFRecordDataset, num_parallel_calls=AUTO)
    else:
        dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTO)
        
    dataset = dataset.with_options(ignore_order)
    
    dataset = dataset.map(lambda x: read_tfrecord(x, labeled=labeled), num_parallel_calls=AUTO)
    
    if augment:
        dataset = dataset.map(data_augment, num_parallel_calls=AUTO)
        
    dataset = dataset.map(scale_image, num_parallel_calls=AUTO)
    dataset = dataset.map(prepare_image, num_parallel_calls=AUTO)
    
    
    if labeled:
        dataset = dataset.map(conf_output, num_parallel_calls=AUTO)
    
    
    if not ordered:
        dataset = dataset.shuffle(2048)
    if repeated:
        dataset = dataset.repeat()
        
    dataset = dataset.batch(BATCH_SIZE)
    
    if cached:
        dataset = dataset.cache()
    dataset = dataset.prefetch(AUTO)
    return dataset

def conf_output(image, label):
    """
        Configure the output of the dataset.
    """
    aux_label = [0.]
#     if tf.math.argmax(label, axis=-1) == 4: # Healthy
    if tf.math.argmax(label, axis=-1) == 3: # CMD
        aux_label = [1.]
    return (image, (label, aux_label))

# %% [markdown]
# # Training data samples (with augmentation)

# %%
# train_dataset = get_dataset(FILENAMES_COMP, ordered=True, augment=True)
# train_iter = iter(train_dataset.unbatch().batch(20))

# display_batch_of_images(next(train_iter))
# display_batch_of_images(next(train_iter))

# %% [markdown]
# # Model

# %%
def model_fn(input_shape, N_CLASSES):
    inputs = L.Input(shape=input_shape, name='input_image')
    base_model = efn.EfficientNetB5(input_tensor=inputs, 
                                    include_top=False, 
                                    weights='noisy-student', 
                                    pooling='avg')

    base_model.trainable = False

    x = L.Dropout(.25)(base_model.output)
    output = L.Dense(N_CLASSES, activation='softmax', name='output')(x)
    output_healthy = L.Dense(1, activation='sigmoid', name='output_healthy')(x)
    
    model = Model(inputs=inputs, outputs=[output, output_healthy])

    return model

# %% [markdown]
# ### Learning rate schedule

# %%
lr_start = 1e-8
lr_min = 1e-6
lr_max = LEARNING_RATE
num_cycles = 3.
warmup_epochs = 3
hold_max_epochs = 0
total_epochs = EPOCHS
step_size = (NUM_TRAINING_IMAGES//BATCH_SIZE)
hold_max_steps = hold_max_epochs * step_size
total_steps = total_epochs * step_size
warmup_steps = warmup_epochs * step_size


def lrfn(total_steps, warmup_steps=0, lr_start=1e-4, lr_max=1e-3, lr_min=1e-4, num_cycles=1.):
    @tf.function
    def cosine_with_hard_restarts_schedule_with_warmup_(step):
        """ Create a schedule with a learning rate that decreases following the
        values of the cosine function with several hard restarts, after a warmup
        period during which it increases linearly between 0 and 1.
        """

        if step < warmup_steps:
            lr = (lr_max - lr_start) / warmup_steps * step + lr_start
        else:
            progress = (step - warmup_steps) / (total_steps - warmup_steps)
            lr = lr_max * (0.5 * (1.0 + tf.math.cos(np.pi * ((num_cycles * progress) % 1.0))))
            if lr_min is not None:
                lr = tf.math.maximum(lr_min, float(lr))
        return lr
    return cosine_with_hard_restarts_schedule_with_warmup_

lrfn_fn = lrfn(total_steps, warmup_steps, lr_start, lr_max, lr_min, num_cycles)
rng = [i for i in range(total_steps)]
y = [lrfn_fn(tf.cast(x, tf.float32)) for x in rng]

sns.set(style='whitegrid')
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)

print(f'{total_steps} total steps and {step_size} steps per epoch')
print(f'Learning rate schedule: {y[0]:.3g} to {max(y):.3g} to {y[-1]:.3g}')
# Out:
# 13563 total steps and 411 steps per epoch
# Learning rate schedule: 1e-08 to 8e-05 to 1e-06

# %% [markdown]
# # Training

# %%
skf = KFold(n_splits=N_FOLDS, shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; oof_names = []; oof_folds = []; history_list = []

for fold,(idxT, idxV) in enumerate(skf.split(np.arange(15))):
    if fold >= FOLDS_USED:
        break
    if tpu: tf.tpu.experimental.initialize_tpu_system(tpu)
    K.clear_session()
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {idxT} VALID: {idxV}')

    # Create train and validation sets
    FILENAMES_COMP = tf.io.gfile.glob([GCS_PATH + '/Id_train%.2i*.tfrec' % x for x in idxT])
    FILENAMES_2019 = tf.io.gfile.glob([GCS_PATH_EXT + '/Id_train%.2i*.tfrec' % x for x in idxT])

#     FILENAMES_COMP_CBB = tf.io.gfile.glob([GCS_PATH_CLASSES + '/CBB%.2i*.tfrec' % x for x in idxT])
#     FILENAMES_COMP_CBSD = tf.io.gfile.glob([GCS_PATH_CLASSES + '/CBSD%.2i*.tfrec' % x for x in idxT])
#     FILENAMES_COMP_CGM = tf.io.gfile.glob([GCS_PATH_CLASSES + '/CGM%.2i*.tfrec' % x for x in idxT])
#     FILENAMES_COMP_Healthy = tf.io.gfile.glob([GCS_PATH_CLASSES + '/Healthy%.2i*.tfrec' % x for x in idxT])
    
#     FILENAMES_2019_CBB = tf.io.gfile.glob([GCS_PATH_EXT_CLASSES + '/CBB%.2i*.tfrec' % x for x in idxT])
#     FILENAMES_2019_CBSD = tf.io.gfile.glob([GCS_PATH_EXT_CLASSES + '/CBSD%.2i*.tfrec' % x for x in idxT])
#     FILENAMES_2019_CGM = tf.io.gfile.glob([GCS_PATH_EXT_CLASSES + '/CGM%.2i*.tfrec' % x for x in idxT])
#     FILENAMES_2019_Healthy = tf.io.gfile.glob([GCS_PATH_EXT_CLASSES + '/Healthy%.2i*.tfrec' % x for x in idxT])

    TRAIN_FILENAMES = (FILENAMES_COMP + FILENAMES_2019)
    
    VALID_FILENAMES = tf.io.gfile.glob([GCS_PATH + '/Id_train%.2i*.tfrec' % x for x in idxV])
    np.random.shuffle(TRAIN_FILENAMES)
    
    ct_train = count_data_items(TRAIN_FILENAMES)
    ct_valid = count_data_items(VALID_FILENAMES)
    
    step_size = (ct_train // BATCH_SIZE)
    valid_step_size = (ct_valid // BATCH_SIZE)
    total_steps = (total_epochs * step_size)
    warmup_steps = (warmup_epochs * step_size)
    
    
    # Build TF datasets
    train_ds = strategy.experimental_distribute_dataset(get_dataset(TRAIN_FILENAMES, repeated=True, augment=True))
    valid_ds = strategy.experimental_distribute_dataset(get_dataset(VALID_FILENAMES, ordered=True, repeated=True))
    train_data_iter = iter(train_ds)
    valid_data_iter = iter(valid_ds)
    
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss = loss_fn(y[0], probabilities[0], label_smoothing=.3)
                aux_loss = aux_loss_fn(y[1], probabilities[1], label_smoothing=.1) * 0.2 # loss weight
                loss = loss + aux_loss
            gradients = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(gradients, model.trainable_variables))
            # update metrics
            train_accuracy.update_state(y[0], probabilities[0])
            train_aux_accuracy.update_state(y[1], probabilities[1])
            train_loss.update_state(loss)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss = loss_fn(y[0], probabilities[0])
            aux_loss = aux_loss_fn(y[1], probabilities[1]) * 0.1 # loss weight
            loss = loss + aux_loss
            # update metrics
            valid_accuracy.update_state(y[0], probabilities[0])
            valid_aux_accuracy.update_state(y[1], probabilities[1])
            valid_loss.update_state(loss)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))
    
    
    # Model
    model_path = f'model_{fold}.h5'
    with strategy.scope():
        model = model_fn((None, None, CHANNELS), N_CLASSES)
        unfreeze_model(model) # unfreeze all layers except "batch normalization"
        
        lrfn_fn = lrfn(total_steps, warmup_steps, lr_start, lr_max, lr_min, num_cycles)
        optimizer = optimizers.SGD(learning_rate=lambda: lrfn_fn(tf.cast(optimizer.iterations, tf.float32)), 
                                   momentum=0.95, nesterov=True)
        loss_fn = losses.categorical_crossentropy
        aux_loss_fn = losses.binary_crossentropy

        train_accuracy = metrics.CategoricalAccuracy()
        valid_accuracy = metrics.CategoricalAccuracy()
        train_aux_accuracy = metrics.BinaryAccuracy()
        valid_aux_accuracy = metrics.BinaryAccuracy()
        train_loss = metrics.Sum()
        valid_loss = metrics.Sum()
        
        metrics_list = [train_accuracy, 
                        valid_accuracy, 
                        train_aux_accuracy, 
                        valid_aux_accuracy, 
                        train_loss, 
                        valid_loss]
    
    
    # Setup training loop
    step = 0
    epoch_steps = 0
    patience_cnt = 0
    best_val = 0
    history = {'loss': [], 'val_loss': [], 
               'accuracy': [], 'val_accuracy': [], 
               'accuracy_aux': [], 'val_accuracy_aux': []}

    ### Train model
    for epoch in range(EPOCHS):
        epoch_start_time = time.time()

        # Run training step
        train_step(train_data_iter)
        epoch_steps += step_size
        step += step_size
            

        # Validation run at the end of each epoch
        if (step // step_size) > epoch:
            # Validation run
            valid_epoch_steps = 0
            valid_step(valid_data_iter)
            valid_epoch_steps += valid_step_size

            # Compute metrics
            history['accuracy_aux'].append(train_aux_accuracy.result().numpy())
            history['accuracy'].append(train_accuracy.result().numpy())
            history['loss'].append(train_loss.result().numpy() / (BATCH_SIZE * epoch_steps))
            history['val_accuracy_aux'].append(valid_aux_accuracy.result().numpy())
            history['val_accuracy'].append(valid_accuracy.result().numpy())
            history['val_loss'].append(valid_loss.result().numpy() / (BATCH_SIZE * valid_epoch_steps))

            # Report metrics
            epoch_time = time.time() - epoch_start_time
            print(f'\nEPOCH {epoch+1}/{EPOCHS}')
            print(f'time: {epoch_time:0.1f}s',
                  f"loss: {history['loss'][-1]:0.4f}",
                  f"accuracy_aux: {history['accuracy_aux'][-1]:0.4f}",
                  f"accuracy: {history['accuracy'][-1]:0.4f}",
                  f"val_loss: {history['val_loss'][-1]:0.4f}",
                  f"val_accuracy_aux: {history['val_accuracy_aux'][-1]:0.4f}",
                  f"val_accuracy: {history['val_accuracy'][-1]:0.4f}",
                  f'lr: {lrfn_fn(tf.cast(optimizer.iterations, tf.int32).numpy()):0.4g}')

            # Early stopping monitor
            if history['val_accuracy'][-1] >= best_val:
                best_val = history['val_accuracy'][-1]
                model.save_weights(model_path)
                print(f'Saved model weights at "{model_path}"')
                patience_cnt = 1
            else:
                patience_cnt += 1
            if patience_cnt > ES_PATIENCE:
                print(f'Epoch {epoch:05d}: early stopping')
                break

                
            # Set up next epoch
            epoch_steps = 0
            for metric in metrics_list:
                metric.reset_states()
    
    
    ### RESULTS
    print(f"#### FOLD {fold+1} OOF Accuracy = {np.max(history['val_accuracy']):.3f}")
    
    history_list.append(history)
    # Load best model weights
    model.load_weights(model_path)

    # OOF predictions
    ds_valid = get_dataset(VALID_FILENAMES, ordered=True)
    oof_folds.append(np.full((ct_valid), fold, dtype='int8'))
    oof_labels.append([target[0].numpy() for img, target in iter(ds_valid.unbatch())])
    x_oof = ds_valid.map(lambda image, target: image)
    oof_pred.append(np.argmax(model.predict(x_oof)[0], axis=-1))
    # OOF names
    ds_valid_names = get_dataset(VALID_FILENAMES, labeled=False, ordered=True)
    oof_names.append(np.array([img_name.numpy().decode('utf-8') for img, img_name in iter(ds_valid_names.unbatch())]))
# Out:
# FOLD: 1
# TRAIN: [ 0  2  3  4  5  7  9 10 11 12 13 14] VALID: [1 6 8]
# Downloading data from https://github.com/qubvel/efficientnet/releases/download/v0.0.1/efficientnet-b5_noisy-student_notop.h5
# 115261440/115255328 [==============================] - 2s 0us/step
#
# EPOCH 1/33
# time: 200.4s loss: 1.4065 accuracy_aux: 0.7180 accuracy: 0.6474 val_loss: 0.7415 val_accuracy_aux: 0.9032 val_accuracy: 0.8073 lr: 2.667e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 2/33
# time: 57.1s loss: 1.1820 accuracy_aux: 0.9142 accuracy: 0.8144 val_loss: 0.6449 val_accuracy_aux: 0.9292 val_accuracy: 0.8497 lr: 5.334e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 3/33
# time: 57.9s loss: 1.1349 accuracy_aux: 0.9339 accuracy: 0.8507 val_loss: 0.6046 val_accuracy_aux: 0.9460 val_accuracy: 0.8698 lr: 8e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 4/33
# time: 58.6s loss: 1.1162 accuracy_aux: 0.9415 accuracy: 0.8624 val_loss: 0.5786 val_accuracy_aux: 0.9491 val_accuracy: 0.8778 lr: 7.804e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 5/33
# time: 58.6s loss: 1.1053 accuracy_aux: 0.9452 accuracy: 0.8721 val_loss: 0.5861 val_accuracy_aux: 0.9505 val_accuracy: 0.8807 lr: 7.236e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 6/33
# time: 58.3s loss: 1.0959 accuracy_aux: 0.9479 accuracy: 0.8787 val_loss: 0.5687 val_accuracy_aux: 0.9508 val_accuracy: 0.8857 lr: 6.351e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 7/33
# time: 58.1s loss: 1.0869 accuracy_aux: 0.9492 accuracy: 0.8837 val_loss: 0.5657 val_accuracy_aux: 0.9579 val_accuracy: 0.8902 lr: 5.236e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 8/33
# time: 58.0s loss: 1.0798 accuracy_aux: 0.9538 accuracy: 0.8893 val_loss: 0.5509 val_accuracy_aux: 0.9581 val_accuracy: 0.8892 lr: 4e-05
#
# EPOCH 9/33
# time: 58.1s loss: 1.0767 accuracy_aux: 0.9547 accuracy: 0.8930 val_loss: 0.5471 val_accuracy_aux: 0.9581 val_accuracy: 0.8937 lr: 2.764e-05
# Saved model weights at "model_0.h5"
#
# EPOCH 10/33
# time: 58.0s loss: 1.0695 accuracy_aux: 0.9556 accuracy: 0.8969 val_loss: 0.5479 val_accuracy_aux: 0.9567 val_accuracy: 0.8930 lr: 1.649e-05
#
# EPOCH 11/33
# time: 57.6s loss: 1.0647 accuracy_aux: 0.9575 accuracy: 0.8976 val_loss: 0.5442 val_accuracy_aux: 0.9574 val_accuracy: 0.8961 lr: 7.639e-06
# Saved model weights at "model_0.h5"
#
# EPOCH 12/33
# time: 58.2s loss: 1.0641 accuracy_aux: 0.9579 accuracy: 0.8996 val_loss: 0.5396 val_accuracy_aux: 0.9583 val_accuracy: 0.8944 lr: 1.958e-06
#
# EPOCH 13/33
# time: 58.4s loss: 1.0615 accuracy_aux: 0.9593 accuracy: 0.9021 val_loss: 0.5389 val_accuracy_aux: 0.9586 val_accuracy: 0.8954 lr: 8e-05
#
# EPOCH 14/33
# time: 58.0s loss: 1.0793 accuracy_aux: 0.9520 accuracy: 0.8889 val_loss: 0.5423 val_accuracy_aux: 0.9581 val_accuracy: 0.8918 lr: 7.804e-05
#
# EPOCH 15/33
# time: 58.9s loss: 1.0766 accuracy_aux: 0.9544 accuracy: 0.8923 val_loss: 0.5505 val_accuracy_aux: 0.9557 val_accuracy: 0.8913 lr: 7.236e-05
#
# EPOCH 16/33
# time: 58.2s loss: 1.0739 accuracy_aux: 0.9549 accuracy: 0.8926 val_loss: 0.5606 val_accuracy_aux: 0.9545 val_accuracy: 0.8894 lr: 6.351e-05
#
# EPOCH 17/33
# time: 58.4s loss: 1.0707 accuracy_aux: 0.9538 accuracy: 0.8933 val_loss: 0.5556 val_accuracy_aux: 0.9541 val_accuracy: 0.8880 lr: 5.236e-05
#
# EPOCH 18/33
# time: 58.2s loss: 1.0637 accuracy_aux: 0.9574 accuracy: 0.9009 val_loss: 0.5419 val_accuracy_aux: 0.9564 val_accuracy: 0.8935 lr: 4e-05
#
# EPOCH 19/33
# time: 58.5s loss: 1.0583 accuracy_aux: 0.9594 accuracy: 0.9034 val_loss: 0.5441 val_accuracy_aux: 0.9567 val_accuracy: 0.8954 lr: 2.764e-05
#
# EPOCH 20/33
# time: 58.2s loss: 1.0583 accuracy_aux: 0.9591 accuracy: 0.9061 val_loss: 0.5508 val_accuracy_aux: 0.9569 val_accuracy: 0.8939 lr: 1.649e-05
#
# EPOCH 21/33
# time: 57.9s loss: 1.0509 accuracy_aux: 0.9622 accuracy: 0.9089 val_loss: 0.5354 val_accuracy_aux: 0.9579 val_accuracy: 0.8956 lr: 7.639e-06
# Epoch 00020: early stopping
# #### FOLD 1 OOF Accuracy = 0.896
#
# FOLD: 2
# TRAIN: [ 0  1  2  3  5  6  7  8 10 11 12 13] VALID: [ 4  9 14]
#
# EPOCH 1/33
# time: 178.9s loss: 1.4068 accuracy_aux: 0.7185 accuracy: 0.6517 val_loss: 0.8104 val_accuracy_aux: 0.9020 val_accuracy: 0.7801 lr: 2.667e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 2/33
# time: 59.1s loss: 1.1799 accuracy_aux: 0.9151 accuracy: 0.8142 val_loss: 0.6281 val_accuracy_aux: 0.9408 val_accuracy: 0.8563 lr: 5.334e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 3/33
# time: 59.2s loss: 1.1355 accuracy_aux: 0.9331 accuracy: 0.8505 val_loss: 0.6001 val_accuracy_aux: 0.9444 val_accuracy: 0.8717 lr: 8e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 4/33
# time: 59.1s loss: 1.1190 accuracy_aux: 0.9416 accuracy: 0.8622 val_loss: 0.5812 val_accuracy_aux: 0.9500 val_accuracy: 0.8790 lr: 7.804e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 5/33
# time: 59.5s loss: 1.1058 accuracy_aux: 0.9443 accuracy: 0.8714 val_loss: 0.5592 val_accuracy_aux: 0.9512 val_accuracy: 0.8800 lr: 7.236e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 6/33
# time: 59.2s loss: 1.0977 accuracy_aux: 0.9462 accuracy: 0.8756 val_loss: 0.5848 val_accuracy_aux: 0.9536 val_accuracy: 0.8857 lr: 6.351e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 7/33
# time: 60.2s loss: 1.0917 accuracy_aux: 0.9478 accuracy: 0.8804 val_loss: 0.5497 val_accuracy_aux: 0.9562 val_accuracy: 0.8911 lr: 5.236e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 8/33
# time: 59.4s loss: 1.0845 accuracy_aux: 0.9527 accuracy: 0.8849 val_loss: 0.5459 val_accuracy_aux: 0.9545 val_accuracy: 0.8911 lr: 4e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 9/33
# time: 57.8s loss: 1.0761 accuracy_aux: 0.9534 accuracy: 0.8916 val_loss: 0.5465 val_accuracy_aux: 0.9567 val_accuracy: 0.8906 lr: 2.764e-05
#
# EPOCH 10/33
# time: 57.7s loss: 1.0722 accuracy_aux: 0.9557 accuracy: 0.8943 val_loss: 0.5480 val_accuracy_aux: 0.9579 val_accuracy: 0.8963 lr: 1.649e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 11/33
# time: 57.2s loss: 1.0677 accuracy_aux: 0.9561 accuracy: 0.8981 val_loss: 0.5353 val_accuracy_aux: 0.9588 val_accuracy: 0.8970 lr: 7.639e-06
# Saved model weights at "model_1.h5"
#
# EPOCH 12/33
# time: 57.2s loss: 1.0633 accuracy_aux: 0.9583 accuracy: 0.9027 val_loss: 0.5387 val_accuracy_aux: 0.9576 val_accuracy: 0.8965 lr: 1.958e-06
#
# EPOCH 13/33
# time: 57.6s loss: 1.0632 accuracy_aux: 0.9596 accuracy: 0.8999 val_loss: 0.5371 val_accuracy_aux: 0.9583 val_accuracy: 0.8980 lr: 8e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 14/33
# time: 57.3s loss: 1.0781 accuracy_aux: 0.9520 accuracy: 0.8895 val_loss: 0.5434 val_accuracy_aux: 0.9605 val_accuracy: 0.8954 lr: 7.804e-05
#
# EPOCH 15/33
# time: 57.3s loss: 1.0774 accuracy_aux: 0.9546 accuracy: 0.8905 val_loss: 0.5271 val_accuracy_aux: 0.9595 val_accuracy: 0.8949 lr: 7.236e-05
#
# EPOCH 16/33
# time: 57.6s loss: 1.0755 accuracy_aux: 0.9528 accuracy: 0.8906 val_loss: 0.5539 val_accuracy_aux: 0.9562 val_accuracy: 0.8937 lr: 6.351e-05
#
# EPOCH 17/33
# time: 57.0s loss: 1.0718 accuracy_aux: 0.9544 accuracy: 0.8941 val_loss: 0.5601 val_accuracy_aux: 0.9593 val_accuracy: 0.8973 lr: 5.236e-05
#
# EPOCH 18/33
# time: 57.8s loss: 1.0657 accuracy_aux: 0.9570 accuracy: 0.9002 val_loss: 0.5296 val_accuracy_aux: 0.9590 val_accuracy: 0.8975 lr: 4e-05
#
# EPOCH 19/33
# time: 57.7s loss: 1.0603 accuracy_aux: 0.9589 accuracy: 0.9049 val_loss: 0.5472 val_accuracy_aux: 0.9595 val_accuracy: 0.8942 lr: 2.764e-05
#
# EPOCH 20/33
# time: 57.7s loss: 1.0573 accuracy_aux: 0.9597 accuracy: 0.9067 val_loss: 0.5357 val_accuracy_aux: 0.9586 val_accuracy: 0.8991 lr: 1.649e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 21/33
# time: 58.6s loss: 1.0528 accuracy_aux: 0.9606 accuracy: 0.9082 val_loss: 0.5308 val_accuracy_aux: 0.9590 val_accuracy: 0.8973 lr: 7.639e-06
#
# EPOCH 22/33
# time: 57.5s loss: 1.0515 accuracy_aux: 0.9622 accuracy: 0.9087 val_loss: 0.5329 val_accuracy_aux: 0.9593 val_accuracy: 0.9018 lr: 1.958e-06
# Saved model weights at "model_1.h5"
#
# EPOCH 23/33
# time: 58.0s loss: 1.0495 accuracy_aux: 0.9635 accuracy: 0.9116 val_loss: 0.5301 val_accuracy_aux: 0.9607 val_accuracy: 0.9020 lr: 8e-05
# Saved model weights at "model_1.h5"
#
# EPOCH 24/33
# time: 58.4s loss: 1.0652 accuracy_aux: 0.9567 accuracy: 0.9007 val_loss: 0.5516 val_accuracy_aux: 0.9598 val_accuracy: 0.8937 lr: 7.804e-05
#
# EPOCH 25/33
# time: 57.2s loss: 1.0646 accuracy_aux: 0.9565 accuracy: 0.9007 val_loss: 0.5372 val_accuracy_aux: 0.9581 val_accuracy: 0.8949 lr: 7.236e-05
#
# EPOCH 26/33
# time: 57.2s loss: 1.0617 accuracy_aux: 0.9594 accuracy: 0.9030 val_loss: 0.5496 val_accuracy_aux: 0.9600 val_accuracy: 0.8968 lr: 6.351e-05
#
# EPOCH 27/33
# time: 57.4s loss: 1.0615 accuracy_aux: 0.9574 accuracy: 0.9038 val_loss: 0.5387 val_accuracy_aux: 0.9595 val_accuracy: 0.8918 lr: 5.236e-05
#
# EPOCH 28/33
# time: 57.5s loss: 1.0570 accuracy_aux: 0.9602 accuracy: 0.9047 val_loss: 0.5465 val_accuracy_aux: 0.9550 val_accuracy: 0.8949 lr: 4e-05
#
# EPOCH 29/33
# time: 58.1s loss: 1.0482 accuracy_aux: 0.9628 accuracy: 0.9134 val_loss: 0.5531 val_accuracy_aux: 0.9588 val_accuracy: 0.8932 lr: 2.764e-05
#
# EPOCH 30/33
# time: 57.7s loss: 1.0477 accuracy_aux: 0.9634 accuracy: 0.9127 val_loss: 0.5416 val_accuracy_aux: 0.9590 val_accuracy: 0.8961 lr: 1.649e-05
#
# EPOCH 31/33
# time: 57.7s loss: 1.0425 accuracy_aux: 0.9640 accuracy: 0.9174 val_loss: 0.5328 val_accuracy_aux: 0.9609 val_accuracy: 0.8980 lr: 7.639e-06
#
# EPOCH 32/33
# time: 57.5s loss: 1.0415 accuracy_aux: 0.9660 accuracy: 0.9171 val_loss: 0.5324 val_accuracy_aux: 0.9605 val_accuracy: 0.8994 lr: 1.958e-06
#
# EPOCH 33/33
# time: 57.6s loss: 1.0409 accuracy_aux: 0.9656 accuracy: 0.9173 val_loss: 0.5323 val_accuracy_aux: 0.9600 val_accuracy: 0.8984 lr: 8e-05
# Epoch 00032: early stopping
# #### FOLD 2 OOF Accuracy = 0.902
#
# FOLD: 3
# TRAIN: [ 0  1  3  4  5  6  7  8  9 11 12 14] VALID: [ 2 10 13]
#
# EPOCH 1/33
# time: 195.2s loss: 1.4139 accuracy_aux: 0.7011 accuracy: 0.6484 val_loss: 0.7529 val_accuracy_aux: 0.8857 val_accuracy: 0.8142 lr: 2.667e-05
# Saved model weights at "model_2.h5"
#
# EPOCH 2/33
# time: 55.9s loss: 1.1816 accuracy_aux: 0.9098 accuracy: 0.8184 val_loss: 0.6032 val_accuracy_aux: 0.9413 val_accuracy: 0.8662 lr: 5.334e-05
# Saved model weights at "model_2.h5"
#
# EPOCH 3/33
# time: 54.9s loss: 1.1387 accuracy_aux: 0.9324 accuracy: 0.8491 val_loss: 0.6118 val_accuracy_aux: 0.9403 val_accuracy: 0.8693 lr: 8e-05
# Saved model weights at "model_2.h5"
#
# EPOCH 4/33
# time: 57.0s loss: 1.1212 accuracy_aux: 0.9402 accuracy: 0.8596 val_loss: 0.5677 val_accuracy_aux: 0.9508 val_accuracy: 0.8845 lr: 7.804e-05
# Saved model weights at "model_2.h5"
#
# EPOCH 5/33
# time: 55.5s loss: 1.1062 accuracy_aux: 0.9462 accuracy: 0.8700 val_loss: 0.5659 val_accuracy_aux: 0.9413 val_accuracy: 0.8769 lr: 7.236e-05
#
# EPOCH 6/33
# time: 56.0s loss: 1.0983 accuracy_aux: 0.9466 accuracy: 0.8759 val_loss: 0.5277 val_accuracy_aux: 0.9569 val_accuracy: 0.8928 lr: 6.351e-05
# Saved model weights at "model_2.h5"
#
# EPOCH 7/33
# time: 56.4s loss: 1.0899 accuracy_aux: 0.9498 accuracy: 0.8811 val_loss: 0.5310 val_accuracy_aux: 0.9567 val_accuracy: 0.8942 lr: 5.236e-05
# Saved model weights at "model_2.h5"
#
# EPOCH 8/33
# time: 55.7s loss: 1.0832 accuracy_aux: 0.9521 accuracy: 0.8848 val_loss: 0.5412 val_accuracy_aux: 0.9571 val_accuracy: 0.8918 lr: 4e-05
#
# EPOCH 9/33
# time: 55.8s loss: 1.0775 accuracy_aux: 0.9537 accuracy: 0.8900 val_loss: 0.5430 val_accuracy_aux: 0.9567 val_accuracy: 0.8987 lr: 2.764e-05
# Saved model weights at "model_2.h5"
#
# EPOCH 10/33
# time: 56.1s loss: 1.0723 accuracy_aux: 0.9553 accuracy: 0.8927 val_loss: 0.5420 val_accuracy_aux: 0.9571 val_accuracy: 0.8987 lr: 1.649e-05
# Saved model weights at "model_2.h5"
#
# EPOCH 11/33
# time: 55.8s loss: 1.0661 accuracy_aux: 0.9583 accuracy: 0.8997 val_loss: 0.5312 val_accuracy_aux: 0.9581 val_accuracy: 0.9018 lr: 7.639e-06
# Saved model weights at "model_2.h5"
#
# EPOCH 12/33
# time: 56.5s loss: 1.0653 accuracy_aux: 0.9579 accuracy: 0.8991 val_loss: 0.5290 val_accuracy_aux: 0.9581 val_accuracy: 0.8987 lr: 1.958e-06
#
# EPOCH 13/33
# time: 56.1s loss: 1.0638 accuracy_aux: 0.9587 accuracy: 0.8996 val_loss: 0.5287 val_accuracy_aux: 0.9593 val_accuracy: 0.8991 lr: 8e-05
#
# EPOCH 14/33
# time: 56.9s loss: 1.0785 accuracy_aux: 0.9527 accuracy: 0.8914 val_loss: 0.5699 val_accuracy_aux: 0.9555 val_accuracy: 0.8909 lr: 7.804e-05
#
# EPOCH 15/33
# time: 55.4s loss: 1.0809 accuracy_aux: 0.9513 accuracy: 0.8869 val_loss: 0.5396 val_accuracy_aux: 0.9583 val_accuracy: 0.9008 lr: 7.236e-05
#
# EPOCH 16/33
# time: 56.1s loss: 1.0751 accuracy_aux: 0.9549 accuracy: 0.8931 val_loss: 0.5400 val_accuracy_aux: 0.9567 val_accuracy: 0.8930 lr: 6.351e-05
#
# EPOCH 17/33
# time: 55.7s loss: 1.0706 accuracy_aux: 0.9551 accuracy: 0.8964 val_loss: 0.5402 val_accuracy_aux: 0.9586 val_accuracy: 0.8980 lr: 5.236e-05
#
# EPOCH 18/33
# time: 55.2s loss: 1.0646 accuracy_aux: 0.9576 accuracy: 0.9003 val_loss: 0.5466 val_accuracy_aux: 0.9567 val_accuracy: 0.8970 lr: 4e-05
#
# EPOCH 19/33
# time: 55.7s loss: 1.0625 accuracy_aux: 0.9591 accuracy: 0.9005 val_loss: 0.5264 val_accuracy_aux: 0.9600 val_accuracy: 0.9025 lr: 2.764e-05
# Saved model weights at "model_2.h5"
#
# EPOCH 20/33
# time: 54.2s loss: 1.0603 accuracy_aux: 0.9590 accuracy: 0.9009 val_loss: 0.5327 val_accuracy_aux: 0.9598 val_accuracy: 0.9006 lr: 1.649e-05
#
# EPOCH 21/33
# time: 54.3s loss: 1.0558 accuracy_aux: 0.9606 accuracy: 0.9040 val_loss: 0.5300 val_accuracy_aux: 0.9593 val_accuracy: 0.9001 lr: 7.639e-06
#
# EPOCH 22/33
# time: 54.4s loss: 1.0527 accuracy_aux: 0.9606 accuracy: 0.9082 val_loss: 0.5256 val_accuracy_aux: 0.9593 val_accuracy: 0.9015 lr: 1.958e-06
#
# EPOCH 23/33
# time: 54.9s loss: 1.0523 accuracy_aux: 0.9618 accuracy: 0.9079 val_loss: 0.5283 val_accuracy_aux: 0.9583 val_accuracy: 0.9001 lr: 8e-05
#
# EPOCH 24/33
# time: 56.1s loss: 1.0632 accuracy_aux: 0.9575 accuracy: 0.9011 val_loss: 0.5567 val_accuracy_aux: 0.9560 val_accuracy: 0.8935 lr: 7.804e-05
#
# EPOCH 25/33
# time: 55.1s loss: 1.0654 accuracy_aux: 0.9582 accuracy: 0.9000 val_loss: 0.5410 val_accuracy_aux: 0.9557 val_accuracy: 0.8904 lr: 7.236e-05
#
# EPOCH 26/33
# time: 55.4s loss: 1.0627 accuracy_aux: 0.9570 accuracy: 0.9015 val_loss: 0.5578 val_accuracy_aux: 0.9607 val_accuracy: 0.8949 lr: 6.351e-05
#
# EPOCH 27/33
# time: 54.5s loss: 1.0598 accuracy_aux: 0.9600 accuracy: 0.9054 val_loss: 0.5309 val_accuracy_aux: 0.9583 val_accuracy: 0.8999 lr: 5.236e-05
#
# EPOCH 28/33
# time: 54.6s loss: 1.0557 accuracy_aux: 0.9606 accuracy: 0.9079 val_loss: 0.5441 val_accuracy_aux: 0.9586 val_accuracy: 0.8970 lr: 4e-05
#
# EPOCH 29/33
# time: 54.7s loss: 1.0521 accuracy_aux: 0.9620 accuracy: 0.9072 val_loss: 0.5193 val_accuracy_aux: 0.9588 val_accuracy: 0.9018 lr: 2.764e-05
# Epoch 00028: early stopping
# #### FOLD 3 OOF Accuracy = 0.902
#
# FOLD: 4
# TRAIN: [ 0  1  2  4  5  6  8  9 10 12 13 14] VALID: [ 3  7 11]
#
# EPOCH 1/33
# time: 188.8s loss: 1.4098 accuracy_aux: 0.7205 accuracy: 0.6449 val_loss: 0.7358 val_accuracy_aux: 0.9039 val_accuracy: 0.8075 lr: 2.667e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 2/33
# time: 53.6s loss: 1.1833 accuracy_aux: 0.9114 accuracy: 0.8131 val_loss: 0.6176 val_accuracy_aux: 0.9439 val_accuracy: 0.8617 lr: 5.334e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 3/33
# time: 54.2s loss: 1.1387 accuracy_aux: 0.9309 accuracy: 0.8461 val_loss: 0.6051 val_accuracy_aux: 0.9444 val_accuracy: 0.8655 lr: 8e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 4/33
# time: 53.7s loss: 1.1189 accuracy_aux: 0.9401 accuracy: 0.8597 val_loss: 0.5973 val_accuracy_aux: 0.9389 val_accuracy: 0.8700 lr: 7.804e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 5/33
# time: 54.2s loss: 1.1096 accuracy_aux: 0.9428 accuracy: 0.8678 val_loss: 0.5788 val_accuracy_aux: 0.9479 val_accuracy: 0.8741 lr: 7.236e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 6/33
# time: 54.1s loss: 1.0969 accuracy_aux: 0.9470 accuracy: 0.8768 val_loss: 0.5562 val_accuracy_aux: 0.9477 val_accuracy: 0.8826 lr: 6.351e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 7/33
# time: 54.0s loss: 1.0869 accuracy_aux: 0.9517 accuracy: 0.8848 val_loss: 0.5603 val_accuracy_aux: 0.9522 val_accuracy: 0.8852 lr: 5.236e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 8/33
# time: 54.3s loss: 1.0825 accuracy_aux: 0.9503 accuracy: 0.8853 val_loss: 0.5561 val_accuracy_aux: 0.9517 val_accuracy: 0.8842 lr: 4e-05
#
# EPOCH 9/33
# time: 54.7s loss: 1.0756 accuracy_aux: 0.9548 accuracy: 0.8935 val_loss: 0.5525 val_accuracy_aux: 0.9524 val_accuracy: 0.8871 lr: 2.764e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 10/33
# time: 54.2s loss: 1.0729 accuracy_aux: 0.9552 accuracy: 0.8930 val_loss: 0.5582 val_accuracy_aux: 0.9541 val_accuracy: 0.8894 lr: 1.649e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 11/33
# time: 53.9s loss: 1.0670 accuracy_aux: 0.9574 accuracy: 0.8989 val_loss: 0.5465 val_accuracy_aux: 0.9522 val_accuracy: 0.8909 lr: 7.639e-06
# Saved model weights at "model_3.h5"
#
# EPOCH 12/33
# time: 54.5s loss: 1.0652 accuracy_aux: 0.9573 accuracy: 0.8988 val_loss: 0.5460 val_accuracy_aux: 0.9538 val_accuracy: 0.8916 lr: 1.958e-06
# Saved model weights at "model_3.h5"
#
# EPOCH 13/33
# time: 54.3s loss: 1.0609 accuracy_aux: 0.9600 accuracy: 0.9016 val_loss: 0.5440 val_accuracy_aux: 0.9543 val_accuracy: 0.8935 lr: 8e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 14/33
# time: 55.3s loss: 1.0817 accuracy_aux: 0.9528 accuracy: 0.8877 val_loss: 0.5503 val_accuracy_aux: 0.9512 val_accuracy: 0.8875 lr: 7.804e-05
#
# EPOCH 15/33
# time: 54.6s loss: 1.0800 accuracy_aux: 0.9531 accuracy: 0.8872 val_loss: 0.5548 val_accuracy_aux: 0.9508 val_accuracy: 0.8828 lr: 7.236e-05
#
# EPOCH 16/33
# time: 54.8s loss: 1.0725 accuracy_aux: 0.9566 accuracy: 0.8933 val_loss: 0.5433 val_accuracy_aux: 0.9512 val_accuracy: 0.8868 lr: 6.351e-05
#
# EPOCH 17/33
# time: 54.7s loss: 1.0699 accuracy_aux: 0.9569 accuracy: 0.8955 val_loss: 0.5467 val_accuracy_aux: 0.9548 val_accuracy: 0.8911 lr: 5.236e-05
#
# EPOCH 18/33
# time: 55.2s loss: 1.0651 accuracy_aux: 0.9593 accuracy: 0.8985 val_loss: 0.5582 val_accuracy_aux: 0.9519 val_accuracy: 0.8866 lr: 4e-05
#
# EPOCH 19/33
# time: 55.3s loss: 1.0596 accuracy_aux: 0.9613 accuracy: 0.9036 val_loss: 0.5404 val_accuracy_aux: 0.9538 val_accuracy: 0.8935 lr: 2.764e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 20/33
# time: 55.4s loss: 1.0558 accuracy_aux: 0.9606 accuracy: 0.9059 val_loss: 0.5449 val_accuracy_aux: 0.9529 val_accuracy: 0.8920 lr: 1.649e-05
#
# EPOCH 21/33
# time: 54.1s loss: 1.0521 accuracy_aux: 0.9627 accuracy: 0.9099 val_loss: 0.5402 val_accuracy_aux: 0.9534 val_accuracy: 0.8930 lr: 7.639e-06
#
# EPOCH 22/33
# time: 54.7s loss: 1.0492 accuracy_aux: 0.9631 accuracy: 0.9119 val_loss: 0.5409 val_accuracy_aux: 0.9541 val_accuracy: 0.8930 lr: 1.958e-06
#
# EPOCH 23/33
# time: 55.2s loss: 1.0514 accuracy_aux: 0.9621 accuracy: 0.9100 val_loss: 0.5433 val_accuracy_aux: 0.9522 val_accuracy: 0.8909 lr: 8e-05
#
# EPOCH 24/33
# time: 55.5s loss: 1.0675 accuracy_aux: 0.9568 accuracy: 0.8985 val_loss: 0.5645 val_accuracy_aux: 0.9512 val_accuracy: 0.8845 lr: 7.804e-05
#
# EPOCH 25/33
# time: 54.8s loss: 1.0665 accuracy_aux: 0.9572 accuracy: 0.8971 val_loss: 0.5495 val_accuracy_aux: 0.9538 val_accuracy: 0.8925 lr: 7.236e-05
#
# EPOCH 26/33
# time: 55.7s loss: 1.0606 accuracy_aux: 0.9585 accuracy: 0.9020 val_loss: 0.5448 val_accuracy_aux: 0.9527 val_accuracy: 0.8928 lr: 6.351e-05
#
# EPOCH 27/33
# time: 55.5s loss: 1.0589 accuracy_aux: 0.9608 accuracy: 0.9040 val_loss: 0.5423 val_accuracy_aux: 0.9522 val_accuracy: 0.8932 lr: 5.236e-05
#
# EPOCH 28/33
# time: 54.9s loss: 1.0556 accuracy_aux: 0.9604 accuracy: 0.9081 val_loss: 0.5341 val_accuracy_aux: 0.9543 val_accuracy: 0.8944 lr: 4e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 29/33
# time: 55.2s loss: 1.0489 accuracy_aux: 0.9639 accuracy: 0.9115 val_loss: 0.5440 val_accuracy_aux: 0.9529 val_accuracy: 0.8918 lr: 2.764e-05
#
# EPOCH 30/33
# time: 55.5s loss: 1.0448 accuracy_aux: 0.9648 accuracy: 0.9149 val_loss: 0.5421 val_accuracy_aux: 0.9541 val_accuracy: 0.8944 lr: 1.649e-05
# Saved model weights at "model_3.h5"
#
# EPOCH 31/33
# time: 54.5s loss: 1.0413 accuracy_aux: 0.9667 accuracy: 0.9173 val_loss: 0.5385 val_accuracy_aux: 0.9541 val_accuracy: 0.8923 lr: 7.639e-06
#
# EPOCH 32/33
# time: 54.4s loss: 1.0430 accuracy_aux: 0.9648 accuracy: 0.9171 val_loss: 0.5391 val_accuracy_aux: 0.9555 val_accuracy: 0.8928 lr: 1.958e-06
#
# EPOCH 33/33
# time: 55.3s loss: 1.0375 accuracy_aux: 0.9672 accuracy: 0.9208 val_loss: 0.5369 val_accuracy_aux: 0.9553 val_accuracy: 0.8918 lr: 8e-05
# #### FOLD 4 OOF Accuracy = 0.894
#
# FOLD: 5
# TRAIN: [ 1  2  3  4  6  7  8  9 10 11 13 14] VALID: [ 0  5 12]
#
# EPOCH 1/33
# time: 168.0s loss: 1.4048 accuracy_aux: 0.7263 accuracy: 0.6457 val_loss: 0.7667 val_accuracy_aux: 0.9077 val_accuracy: 0.7945 lr: 2.667e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 2/33
# time: 53.8s loss: 1.1817 accuracy_aux: 0.9117 accuracy: 0.8114 val_loss: 0.6575 val_accuracy_aux: 0.9403 val_accuracy: 0.8497 lr: 5.334e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 3/33
# time: 54.7s loss: 1.1394 accuracy_aux: 0.9322 accuracy: 0.8505 val_loss: 0.5859 val_accuracy_aux: 0.9434 val_accuracy: 0.8691 lr: 8e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 4/33
# time: 54.0s loss: 1.1192 accuracy_aux: 0.9411 accuracy: 0.8632 val_loss: 0.5648 val_accuracy_aux: 0.9512 val_accuracy: 0.8762 lr: 7.804e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 5/33
# time: 54.2s loss: 1.1094 accuracy_aux: 0.9435 accuracy: 0.8686 val_loss: 0.5737 val_accuracy_aux: 0.9512 val_accuracy: 0.8847 lr: 7.236e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 6/33
# time: 54.2s loss: 1.0966 accuracy_aux: 0.9469 accuracy: 0.8765 val_loss: 0.5546 val_accuracy_aux: 0.9524 val_accuracy: 0.8864 lr: 6.351e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 7/33
# time: 53.6s loss: 1.0904 accuracy_aux: 0.9485 accuracy: 0.8810 val_loss: 0.5670 val_accuracy_aux: 0.9517 val_accuracy: 0.8868 lr: 5.236e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 8/33
# time: 54.3s loss: 1.0828 accuracy_aux: 0.9522 accuracy: 0.8844 val_loss: 0.5486 val_accuracy_aux: 0.9500 val_accuracy: 0.8885 lr: 4e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 9/33
# time: 53.8s loss: 1.0796 accuracy_aux: 0.9527 accuracy: 0.8887 val_loss: 0.5485 val_accuracy_aux: 0.9569 val_accuracy: 0.8963 lr: 2.764e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 10/33
# time: 54.8s loss: 1.0731 accuracy_aux: 0.9539 accuracy: 0.8935 val_loss: 0.5456 val_accuracy_aux: 0.9531 val_accuracy: 0.8918 lr: 1.649e-05
#
# EPOCH 11/33
# time: 54.4s loss: 1.0687 accuracy_aux: 0.9559 accuracy: 0.8963 val_loss: 0.5357 val_accuracy_aux: 0.9560 val_accuracy: 0.8970 lr: 7.639e-06
# Saved model weights at "model_4.h5"
#
# EPOCH 12/33
# time: 54.3s loss: 1.0658 accuracy_aux: 0.9584 accuracy: 0.8999 val_loss: 0.5406 val_accuracy_aux: 0.9579 val_accuracy: 0.9001 lr: 1.958e-06
# Saved model weights at "model_4.h5"
#
# EPOCH 13/33
# time: 54.3s loss: 1.0643 accuracy_aux: 0.9575 accuracy: 0.9009 val_loss: 0.5377 val_accuracy_aux: 0.9564 val_accuracy: 0.8996 lr: 8e-05
#
# EPOCH 14/33
# time: 55.1s loss: 1.0836 accuracy_aux: 0.9531 accuracy: 0.8881 val_loss: 0.5488 val_accuracy_aux: 0.9562 val_accuracy: 0.8942 lr: 7.804e-05
#
# EPOCH 15/33
# time: 54.9s loss: 1.0810 accuracy_aux: 0.9517 accuracy: 0.8871 val_loss: 0.5646 val_accuracy_aux: 0.9553 val_accuracy: 0.8875 lr: 7.236e-05
#
# EPOCH 16/33
# time: 54.5s loss: 1.0770 accuracy_aux: 0.9538 accuracy: 0.8907 val_loss: 0.5466 val_accuracy_aux: 0.9531 val_accuracy: 0.8918 lr: 6.351e-05
#
# EPOCH 17/33
# time: 54.9s loss: 1.0705 accuracy_aux: 0.9566 accuracy: 0.8954 val_loss: 0.5551 val_accuracy_aux: 0.9567 val_accuracy: 0.8951 lr: 5.236e-05
#
# EPOCH 18/33
# time: 54.5s loss: 1.0661 accuracy_aux: 0.9568 accuracy: 0.9003 val_loss: 0.5377 val_accuracy_aux: 0.9571 val_accuracy: 0.8975 lr: 4e-05
#
# EPOCH 19/33
# time: 54.7s loss: 1.0620 accuracy_aux: 0.9597 accuracy: 0.9019 val_loss: 0.5481 val_accuracy_aux: 0.9579 val_accuracy: 0.9018 lr: 2.764e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 20/33
# time: 54.9s loss: 1.0578 accuracy_aux: 0.9595 accuracy: 0.9033 val_loss: 0.5289 val_accuracy_aux: 0.9576 val_accuracy: 0.9025 lr: 1.649e-05
# Saved model weights at "model_4.h5"
#
# EPOCH 21/33
# time: 54.5s loss: 1.0571 accuracy_aux: 0.9604 accuracy: 0.9071 val_loss: 0.5322 val_accuracy_aux: 0.9588 val_accuracy: 0.9034 lr: 7.639e-06
# Saved model weights at "model_4.h5"
#
# EPOCH 22/33
# time: 54.8s loss: 1.0527 accuracy_aux: 0.9608 accuracy: 0.9094 val_loss: 0.5308 val_accuracy_aux: 0.9590 val_accuracy: 0.9051 lr: 1.958e-06
# Saved model weights at "model_4.h5"
#
# EPOCH 23/33
# time: 55.1s loss: 1.0494 accuracy_aux: 0.9616 accuracy: 0.9114 val_loss: 0.5303 val_accuracy_aux: 0.9583 val_accuracy: 0.9027 lr: 8e-05
#
# EPOCH 24/33
# time: 55.0s loss: 1.0686 accuracy_aux: 0.9571 accuracy: 0.8969 val_loss: 0.5391 val_accuracy_aux: 0.9560 val_accuracy: 0.8961 lr: 7.804e-05
#
# EPOCH 25/33
# time: 54.9s loss: 1.0692 accuracy_aux: 0.9539 accuracy: 0.8968 val_loss: 0.5430 val_accuracy_aux: 0.9569 val_accuracy: 0.8954 lr: 7.236e-05
#
# EPOCH 26/33
# time: 55.9s loss: 1.0634 accuracy_aux: 0.9569 accuracy: 0.9011 val_loss: 0.5401 val_accuracy_aux: 0.9555 val_accuracy: 0.8970 lr: 6.351e-05
#
# EPOCH 27/33
# time: 55.0s loss: 1.0604 accuracy_aux: 0.9593 accuracy: 0.9016 val_loss: 0.5294 val_accuracy_aux: 0.9588 val_accuracy: 0.9001 lr: 5.236e-05
#
# EPOCH 28/33
# time: 54.9s loss: 1.0561 accuracy_aux: 0.9591 accuracy: 0.9063 val_loss: 0.5432 val_accuracy_aux: 0.9586 val_accuracy: 0.8965 lr: 4e-05
#
# EPOCH 29/33
# time: 54.9s loss: 1.0528 accuracy_aux: 0.9619 accuracy: 0.9066 val_loss: 0.5445 val_accuracy_aux: 0.9600 val_accuracy: 0.9025 lr: 2.764e-05
#
# EPOCH 30/33
# time: 55.2s loss: 1.0476 accuracy_aux: 0.9639 accuracy: 0.9133 val_loss: 0.5451 val_accuracy_aux: 0.9598 val_accuracy: 0.9022 lr: 1.649e-05
#
# EPOCH 31/33
# time: 54.8s loss: 1.0436 accuracy_aux: 0.9645 accuracy: 0.9152 val_loss: 0.5251 val_accuracy_aux: 0.9598 val_accuracy: 0.9041 lr: 7.639e-06
#
# EPOCH 32/33
# time: 54.9s loss: 1.0454 accuracy_aux: 0.9635 accuracy: 0.9137 val_loss: 0.5307 val_accuracy_aux: 0.9602 val_accuracy: 0.9034 lr: 1.958e-06
# Epoch 00031: early stopping
# #### FOLD 5 OOF Accuracy = 0.905

# %% [markdown]
# ## Model loss graph

# %%
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1
# FOLD: 2
# FOLD: 3
# FOLD: 4
# FOLD: 5

# %% [markdown]
# # Model evaluation

# %%
y_true = np.concatenate(oof_labels)
y_true = np.argmax(y_true, axis=-1)
y_pred = np.concatenate(oof_pred)
folds = np.concatenate(oof_folds)
names = np.concatenate(oof_names)

acc = accuracy_score(y_true, y_pred)
print(f'Overall OOF Accuracy = {acc:.3f}')

df_oof = pd.DataFrame({'image_id':names, 'fold':fold, 
                       'target':y_true, 'pred':y_pred})
df_oof.to_csv('oof.csv', index=False)
display(df_oof.head())

print(classification_report(y_true, y_pred, target_names=CLASSES))
# Out:
# Overall OOF Accuracy = 0.899
#          image_id  fold  target  pred
# 0  1000201771.jpg     4       3     3
# 1  1000837476.jpg     4       3     3
# 2  1001723730.jpg     4       4     0
# 3  1001749118.jpg     4       3     3
# 4  1008284502.jpg     4       3     3
#                               precision    recall  f1-score   support
#
#     Cassava Bacterial Blight       0.66      0.72      0.69      1086
# Cassava Brown Streak Disease       0.85      0.82      0.84      2189
#         Cassava Green Mottle       0.84      0.81      0.83      2386
#       Cassava Mosaic Disease       0.96      0.98      0.97     13158
#                      Healthy       0.79      0.73      0.76      2576
#
#                     accuracy                           0.90     21395
#                    macro avg       0.82      0.81      0.82     21395
#                 weighted avg       0.90      0.90      0.90     21395

# %% [markdown]
# # Confusion matrix

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 12))
cfn_matrix = confusion_matrix(y_true, y_pred, labels=range(len(CLASSES)))
cfn_matrix = (cfn_matrix.T / cfn_matrix.sum(axis=1)).T
df_cm = pd.DataFrame(cfn_matrix, index=CLASSES, columns=CLASSES)
ax = sns.heatmap(df_cm, cmap='Blues', annot=True, fmt='.2f', linewidths=.5).set_title('Train', fontsize=30)
plt.show()

# %% [markdown]
# # Visualize predictions

# %%
# train_dataset = get_dataset(TRAINING_FILENAMES, ordered=True)
# x_samp, y_samp = dataset_to_numpy_util(train_dataset, 18)
# y_samp = np.argmax(y_samp, axis=-1)

# x_samp_1, y_samp_1 = x_samp[:9,:,:,:], y_samp[:9]
# samp_preds_1 = model.predict(x_samp_1, batch_size=9)
# display_9_images_with_predictions(x_samp_1, samp_preds_1, y_samp_1)

# x_samp_2, y_samp_2 = x_samp[9:,:,:,:], y_samp[9:]
# samp_preds_2 = model.predict(x_samp_2, batch_size=9)
# display_9_images_with_predictions(x_samp_2, samp_preds_2, y_samp_2)
